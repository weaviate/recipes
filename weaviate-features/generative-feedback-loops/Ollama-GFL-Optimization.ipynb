# %%
import dspy
import openai

openai.api_key = "sk-foobar"

gpt4 = dspy.OpenAI(model="gpt-4", max_tokens=4000, model_type="chat")

llama3_ollama = dspy.OllamaLocal(
    model="llama3:instruct",
    max_tokens=4000,
    timeout_s=480
)

dspy.settings.configure(lm=llama3_ollama)

print(llama3_ollama("say hello"))
print(gpt4("say hello"))
# Out:
# ["Hello! It's nice to meet you. Is there something I can help you with, or would you like to chat?"]
# ['Hello! How can I assist you today?']

# %%
# Load blogs into Weaviate
import weaviate

weaviate_client = weaviate.connect_to_local()

weaviate_client.collections.delete("WeaviateBlogChunk")

# %%
import weaviate.classes.config as wvcc

collection = weaviate_client.collections.create(
   name="WeaviateBlogChunk",
   vectorizer_config=wvcc.Configure.Vectorizer.text2vec_ollama
   (
       api_endpoint="http://host.docker.internal:11434",
       model="snowflake-arctic-embed:335m"
   ),
   properties=[
           wvcc.Property(name="content", data_type=wvcc.DataType.TEXT),
           wvcc.Property(name="inspired_question", data_type=wvcc.DataType.TEXT, skip_vectorization=True)
     ]
)

# %%
import os
import re


def chunk_list(lst, chunk_size):
    """Break a list into chunks of the specified size."""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]


def split_into_sentences(text):
    """Split text into sentences using regular expressions."""
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    return [sentence.strip() for sentence in sentences if sentence.strip()]


def read_and_chunk_index_files(main_folder_path):
    """Read index.md files from subfolders, split into sentences, and chunk every 5 sentences."""
    blog_chunks = []
    for folder_name in os.listdir(main_folder_path):
        subfolder_path = os.path.join(main_folder_path, folder_name)
        if os.path.isdir(subfolder_path):
            index_file_path = os.path.join(subfolder_path, 'index.mdx')
            if os.path.isfile(index_file_path):
                with open(index_file_path, 'r', encoding='utf-8') as file:
                    content = file.read()
                    sentences = split_into_sentences(content)
                    sentence_chunks = chunk_list(sentences, 5)
                    sentence_chunks = [' '.join(chunk) for chunk in sentence_chunks]
                    blog_chunks.extend(sentence_chunks)
    return blog_chunks


# Example usage
main_folder_path = '../datasets/weaviate-blogs'
blog_chunks = read_and_chunk_index_files(main_folder_path)


print(f"{len(blog_chunks)}\n")
print(blog_chunks[0])
# Out:
# 1182
#
# ---
# title: Combining LangChain and Weaviate
# slug: combining-langchain-and-weaviate
# authors: [erika]
# date: 2023-02-21
# tags: ['integrations']
# image: ./img/hero.png
# description: "LangChain is one of the most exciting new tools in AI. It helps overcome many limitations of LLMs, such as hallucination and limited input lengths."
# ---
# ![Combining LangChain and Weaviate](./img/hero.png)
#
# Large Language Models (LLMs) have revolutionized the way we interact and communicate with computers. These machines can understand and generate human-like language on a massive scale. LLMs are a versatile tool that is seen in many applications like chatbots, content creation, and much more. Despite being a powerful tool, LLMs have the drawback of being too general.

# %%
from weaviate.util import get_valid_uuid
from uuid import uuid4
import time

blogs = weaviate_client.collections.get("WeaviateBlogChunk")

blog_chunk_uuids = []

start = time.time()
for idx, blog_chunk in enumerate(blog_chunks):
    id = get_valid_uuid(uuid4())
    blog_chunk_uuids.append(id)
    upload = blogs.data.insert(
        properties={
           "content": blog_chunk
        },
        uuid=id
    )

print(f"Uploaded and vectorized {len(blog_chunks)} blog chunks in {time.time() - start} seconds.")
# Out:
# Uploaded and vectorized 1182 blog chunks in 111.69951510429382 seconds.

# %%
from pydantic import BaseModel, field_validator

class UpdatedPropertyValue(BaseModel):
    property_value: str

    @field_validator("property_value")
    def check_starts_with(cls, v):
        invalid_prefixes = [
            "Property Name",
            "References",
            "Instruction",
            "Property Value",
        ]
        for prefix in invalid_prefixes:
            if v.startswith(prefix):
                raise ValueError(f"property_value cannot start with '{prefix}'")
        return v


class UpdateProperty(dspy.Signature):
    """Your task is to generate the value of a property by following the given instruction
    using the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!"""

    property_name: str = dspy.InputField(
        desc="The name of the property that you should update."
    )
    references: str = dspy.InputField(
        desc="The name-value property pairs that you should refer to while updating the property."
    )
    instruction: str = dspy.InputField(
        desc="The instruction that you should strictly follow while updating the property."
    )
    property_value: UpdatedPropertyValue = dspy.OutputField(
        desc="VERY IMPORTANT!! ONLY OUTPUT THIS VALUE AND *NOTHING* ELSE!!!"
    )


class Program(dspy.Module):
    def __init__(self) -> None:
        self.predict = dspy.Predict(UpdateProperty)

    def forward(self, property_name: str, references: str, instruction: str) -> str:
        prediction = self.predict(
            property_name=property_name, references=references, instruction=instruction
        ).property_value
        return dspy.Prediction(property_value=prediction)

# %%
program = Program()

instruction = """
Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information. 
VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
"""

property_name="inspired_query"

# %%
import random

def create_training_set(num_samples, uuids, weaviate_index, property_name, instruction):
    training_set = []
    for i in range(num_samples):
        uuid = random.choice(uuids)
        obj = weaviate_index.query.fetch_object_by_id(uuid)
        references = " ".join(f"{k}: {v}" for k, v in obj.properties.items())
        training_set.append(dspy.Example(
            property_name=property_name,
            references=references,
            instruction=instruction
        ).with_inputs('property_name', 'references', 'instruction'))
    return training_set

trainset = create_training_set(
    num_samples=20,
    uuids=blog_chunk_uuids,
    weaviate_index=blogs,
    property_name=property_name,
    instruction=instruction
)

# %%
class TypedGFLEvaluator(dspy.Signature):
    """A system has been given the assignment to generate the value of a property by following the instruction using the provided name-value property references.
Evaluate how well the response follows the instruction on a scale of 1 to 5. Please note it is EXTREMELY IMPORTANT that the property_value strictly contains the value and nothing else in the response. If it does have something other than the value itself, please rate it very low."""
    
    property_value: str = dspy.InputField(
        desc="The response from the system."
    )
    property_name = dspy.InputField(
        desc="The name of the property that you should update."
    )
    references = dspy.InputField(
        desc="The name-value property pairs that you should refer to while updating the property."
    )
    instruction = dspy.InputField(
        desc="The prompt to use when generating the updated property value."
    )
    rating: float = dspy.OutputField(desc="A float rating between 1 and 5. IMPORTANT!! ONLY OUTPUT THE RATING!!")

class OnlyOutputsPropertyValue(dspy.Signature):
    """It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1."""

    property_value: str = dspy.InputField(
        desc="The response from the system containing the property value."
    )
    rating: int = dspy.OutputField(desc="An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!!")

def MetricWrapper(gold, pred, trace=None):
    try:
        # Evaluate the quality of the instruction following
        quality_result = dspy.TypedPredictor(TypedGFLEvaluator)(
            property_value=pred.property_value,
            property_name=gold.property_name,
            references=gold.references,
            instruction=gold.instruction
        )
        quality_rating = float(quality_result.rating)
        quality_rating = max(0, min(5, quality_rating))

        # Evaluate if only the property value is output
        only_value_result = dspy.TypedPredictor(OnlyOutputsPropertyValue)(
            property_value=pred.property_value
        )
        only_value_rating = int(only_value_result.rating)

        # Combine the ratings with the specified weighting
        # The OnlyOutputsPropertyValue rating is 5 times more important
        combined_rating = (quality_rating + 5 * only_value_rating * 5) / 6

        return combined_rating
    except ValueError:
        # If conversion fails, return a default middle score
        print(f"Warning: Unable to parse rating.")
        return 2.5

# %% [markdown]
# # Hypothesis: Turn off Examples

# %%
from dspy.teleprompt import MIPROv2

teleprompter = MIPROv2(prompt_model=gpt4, task_model=llama3_ollama, metric=MetricWrapper, num_candidates=10, init_temperature=1.0)
kwargs = dict(num_threads=1, display_progress=True, display_table=0)
MIPRO_compiled_GFL = teleprompter.compile(program, trainset=trainset[:10], num_batches=10, max_bootstrapped_demos=0, max_labeled_demos=0, eval_kwargs=kwargs)
# Out:
# WARNING: Projected Language Model (LM) Calls
#
# Please be advised that based on the parameters you have set, the maximum number of LM calls is projected as follows:
#
#
# - Prompt Model: 10 data summarizer calls + 10 * 1 lm calls in program + (2) lm calls in program aware proposer = 22 prompt model calls
# - Task Model: 25 examples in minibatch * 10 batches + 10 examples in train set * 1 full evals = 260 task model calls
#
# Estimated Cost Calculation:
#
# Total Cost = (Number of calls to task model * (Avg Input Token Length per Call * Task Model Price per Input Token + Avg Output Token Length per Call * Task Model Price per Output Token)
#             + (Number of calls to prompt model * (Avg Input Token Length per Call * Task Prompt Price per Input Token + Avg Output Token Length per Call * Prompt Model Price per Output Token).
#
# For a preliminary estimate of potential costs, we recommend you perform your own calculations based on the task
# and prompt models you intend to use. If the projected costs exceed your budget or expectations, you may consider:
#
# - Reducing the number of trials (`num_batches`), the size of the trainset, or the number of LM calls in your program.
# - Using a cheaper task model to optimize the prompt.
# To proceed with the execution of this program, please confirm by typing 'y' for yes or 'n' for no.
#
# If you would like to bypass this confirmation step in future executions, set the `requires_permission_to_run` flag to `False` when calling compile.
#
# Awaiting your input...
#
# Do you wish to continue? (y/n): y
# summary: Prediction(
#     summary='The dataset concentrates on the technical aspects and unique functionalities of databases, particularly vector databases, including semantic search capabilities, Chain of Thought reasoning, and the influence of PQ compression on indexing algorithms. The task at hand is to generate a rich, non-verbatim query based on the given blog post content from Weaviate, a Vector Database company, to aid in creating discussion points or research questions for further study. It suggests an emphasis on semantic understanding and knowledge generation more than mere information retrieval.'
# )
# DATA SUMMARY: The dataset concentrates on the technical aspects and unique functionalities of databases, particularly vector databases, including semantic search capabilities, Chain of Thought reasoning, and the influence of PQ compression on indexing algorithms. The task at hand is to generate a rich, non-verbatim query based on the given blog post content from Weaviate, a Vector Database company, to aid in creating discussion points or research questions for further study. It suggests an emphasis on semantic understanding and knowledge generation more than mere information retrieval.
#  10%|████▍                                       | 1/10 [00:14<02:11, 14.66s/it]
#  30%|█████████████▏                              | 3/10 [00:19<00:44,  6.36s/it]
#  20%|████████▊                                   | 2/10 [00:13<00:53,  6.69s/it]
#  10%|████▍                                       | 1/10 [00:05<00:51,  5.76s/it]
#  10%|████▍                                       | 1/10 [00:05<00:49,  5.48s/it]
#  10%|████▍                                       | 1/10 [00:04<00:44,  4.91s/it]
#  10%|████▍                                       | 1/10 [00:07<01:06,  7.35s/it]
#  30%|█████████████▏                              | 3/10 [00:17<00:39,  5.69s/it]
#  30%|█████████████▏                              | 3/10 [00:18<00:43,  6.26s/it]
# [I 2024-06-27 08:28:18,404] A new study created in memory with name: no-name-38108567-9ad2-4a22-9074-4da4a4d57202
# Using a randomly generated configuration for our grounded proposer.
# Selected tip: simple
# PROGRAM DESCRIPTION: 'Current Location'
# References: 'Initial Location: New York, Current Location: Boston, Final Location: Miami'
# Instruction: 'Move two steps South and update the current location'
#
# Result:
# Property Value: 'Washington D.C.'
#
# SUMMARY OF PROGRAM ABOVE:
# The program appears to be designed to solve tasks that require updating property values based on provided references and instructions. The program accomplishes this by using a language model to interpret and execute the instruction, using the references and property name as context. The property name identifies which property to update, the references provide name-value pairs for context, and the instruction provides a command to follow. The output is the new value of the specified property, following the instruction.
#
# For example, given the property name 'Current Location', and a reference that states the 'Initial Location' was 'New York' and the 'Current Location' is 'Boston', and an instruction to move two steps south, the program would output 'Washington D.C.' as the updated property value. It can be inferred that the steps are referring to significant location markers and using some internal representation, two steps south from 'Boston' is 'Washington D.C.' It's worth noting that the system's output should strictly be the updated property value, with no additional text or context.
# Warning: __init__ method not found in the program code.
# task_demos
#
#
#
# Use the information below to learn about a task that we are trying to solve using calls to an LM, then generate a new instruction that will be used to prompt a Language Model to better solve the task.
#
# ---
#
# Follow the following format.
#
# DATASET SUMMARY: A description of the dataset that we are using.
#
# PROGRAM CODE: Language model program designed to solve a particular task.
#
# PROGRAM DESCRIPTION: Summary of the task the program is designed to solve, and how it goes about solving it.
#
# MODULE: The module to create an instruction for.
#
# TASK DEMO(S): Example inputs/outputs of our module.
#
# BASIC INSTRUCTION: Basic instruction.
#
# TIP: A suggestion for how to go about generating the new instruction.
#
# PROPOSED INSTRUCTION: Propose an instruction that will be used to prompt a Language Model to perform this task.
#
# ---
#
# DATASET SUMMARY: The dataset concentrates on the technical aspects and unique functionalities of databases, particularly vector databases, including semantic search capabilities, Chain of Thought reasoning, and the influence of PQ compression on indexing algorithms. The task at hand is to generate a rich, non-verbatim query based on the given blog post content from Weaviate, a Vector Database company, to aid in creating discussion points or research questions for further study. It suggests an emphasis on semantic understanding and knowledge generation more than mere information retrieval.
#
# PROGRAM CODE:
# UpdateProperty(property_name, references, instruction -> property_value
#     instructions='Your task is to generate the value of a property by following the given instruction\nusing the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!'
#     property_name = Field(annotation=str required=True json_schema_extra={'desc': 'The name of the property that you should update.', '__dspy_field_type': 'input', 'prefix': 'Property Name:'})
#     references = Field(annotation=str required=True json_schema_extra={'desc': 'The name-value property pairs that you should refer to while updating the property.', '__dspy_field_type': 'input', 'prefix': 'References:'})
#     instruction = Field(annotation=str required=True json_schema_extra={'desc': 'The instruction that you should strictly follow while updating the property.', '__dspy_field_type': 'input', 'prefix': 'Instruction:'})
#     property_value = Field(annotation=UpdatedPropertyValue required=True json_schema_extra={'desc': 'VERY IMPORTANT!! ONLY OUTPUT THIS VALUE AND *NOTHING* ELSE!!!', '__dspy_field_type': 'output', 'prefix': 'Property Value:'})
# )
#
# class Program(dspy.Module):
#     def __init__(self) -> None:
#         self.predict = dspy.Predict(UpdateProperty)
#
#     def forward(self, property_name: str, references: str, instruction: str) -> str:
#         prediction = self.predict(
#             property_name=property_name, references=references, instruction=instruction
#         ).property_value
#         return dspy.Prediction(property_value=prediction)
#
#
# PROGRAM DESCRIPTION: 'Current Location' References: 'Initial Location: New York, Current Location: Boston, Final Location: Miami' Instruction: 'Move two steps South and update the current location' Result: Property Value: 'Washington D.C.' SUMMARY OF PROGRAM ABOVE: The program appears to be designed to solve tasks that require updating property values based on provided references and instructions. The program accomplishes this by using a language model to interpret and execute the instruction, using the references and property name as context. The property name identifies which property to update, the references provide name-value pairs for context, and the instruction provides a command to follow. The output is the new value of the specified property, following the instruction. For example, given the property name 'Current Location', and a reference that states the 'Initial Location' was 'New York' and the 'Current Location' is 'Boston', and an instruction to move two steps south, the program would output 'Washington D.C.' as the updated property value. It can be inferred that the steps are referring to significant location markers and using some internal representation, two steps south from 'Boston' is 'Washington D.C.' It's worth noting that the system's output should strictly be the updated property value, with no additional text or context.
#
# MODULE:
#
# TASK DEMO(S):
#
# BASIC INSTRUCTION:
# Your task is to generate the value of a property by following the given instruction
# using the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!
#
# TIP: Keep the instruction clear and concise.
#
# PROPOSED INSTRUCTION: Follow the instruction strictly, using the name-value property references for context, and provide only the updated property value. Remember, do not include any additional text or context—simply output the result.
#
#
#
# PROPOSED INSTRUCTION: Follow the instruction strictly, using the name-value property references for context, and provide only the updated property value. Remember, do not include any additional text or context—simply output the result.
# PROGRAM DESCRIPTION: The pseudo-code describes a program designed to update a named property using a set of instructions and provided context in the form of name-value pairs. The unique feature of this task is not just updating the property, but doing so by generating the value of the updated property directly from the given instruction, strictly following the guidelines.
#
# In the given example, the task is for a language model to generate a question, named 'inspired_query', based on a given context - the 'references'. The instruction stipulates that the generated question should delve into underlying concepts of a narrative captured in the references, and should emphasise the advantages of semantic search with vector embeddings over traditional methods. The generated question is the output, which is referred to as 'property_value' in the program.
#
# The model works by predicting the updated property value based on the provided property name, the references, and the given instruction. It then makes the response available as the output property_value. While working on this task, the model has been strictly instructed to only output the property value and nothing else.
# Warning: __init__ method not found in the program code.
# task_demos Property Name: inspired_query
# References: inspired_question: None content: Chain of thought is a method commonly used to assist the language model with its reasoning capability. [AutoGPT](https://github.com/Significant-Gravitas/Auto-GPT) demonstrated how a model could run autonomously to complete various tasks without much human intervention. This was done by using chain of thought reasoning to break down tasks into intermediate steps. The program would then run continuously until all tasks were completed. Another cutting edge idea in this line of thinking is [Tree-of-Thoughts sampling](https://arxiv.org/abs/2305.10601).
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How can we leverage chain of thought reasoning and Tree-of-Thoughts sampling to revolutionize the way we approach semantic search in vector databases, enabling more accurate and context-aware recommendations?
#
#
#
#
# Use the information below to learn about a task that we are trying to solve using calls to an LM, then generate a new instruction that will be used to prompt a Language Model to better solve the task.
#
# ---
#
# Follow the following format.
#
# DATASET SUMMARY: A description of the dataset that we are using.
#
# PROGRAM CODE: Language model program designed to solve a particular task.
#
# PROGRAM DESCRIPTION: Summary of the task the program is designed to solve, and how it goes about solving it.
#
# MODULE: The module to create an instruction for.
#
# TASK DEMO(S): Example inputs/outputs of our module.
#
# BASIC INSTRUCTION: Basic instruction.
#
# TIP: A suggestion for how to go about generating the new instruction.
#
# PROPOSED INSTRUCTION: Propose an instruction that will be used to prompt a Language Model to perform this task.
#
# ---
#
# DATASET SUMMARY: The dataset concentrates on the technical aspects and unique functionalities of databases, particularly vector databases, including semantic search capabilities, Chain of Thought reasoning, and the influence of PQ compression on indexing algorithms. The task at hand is to generate a rich, non-verbatim query based on the given blog post content from Weaviate, a Vector Database company, to aid in creating discussion points or research questions for further study. It suggests an emphasis on semantic understanding and knowledge generation more than mere information retrieval.
#
# PROGRAM CODE:
# UpdateProperty(property_name, references, instruction -> property_value
#     instructions='Your task is to generate the value of a property by following the given instruction\nusing the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!'
#     property_name = Field(annotation=str required=True json_schema_extra={'desc': 'The name of the property that you should update.', '__dspy_field_type': 'input', 'prefix': 'Property Name:'})
#     references = Field(annotation=str required=True json_schema_extra={'desc': 'The name-value property pairs that you should refer to while updating the property.', '__dspy_field_type': 'input', 'prefix': 'References:'})
#     instruction = Field(annotation=str required=True json_schema_extra={'desc': 'The instruction that you should strictly follow while updating the property.', '__dspy_field_type': 'input', 'prefix': 'Instruction:'})
#     property_value = Field(annotation=UpdatedPropertyValue required=True json_schema_extra={'desc': 'VERY IMPORTANT!! ONLY OUTPUT THIS VALUE AND *NOTHING* ELSE!!!', '__dspy_field_type': 'output', 'prefix': 'Property Value:'})
# )
#
# class Program(dspy.Module):
#     def __init__(self) -> None:
#         self.predict = dspy.Predict(UpdateProperty)
#
#     def forward(self, property_name: str, references: str, instruction: str) -> str:
#         prediction = self.predict(
#             property_name=property_name, references=references, instruction=instruction
#         ).property_value
#         return dspy.Prediction(property_value=prediction)
#
#
# PROGRAM DESCRIPTION: The pseudo-code describes a program designed to update a named property using a set of instructions and provided context in the form of name-value pairs. The unique feature of this task is not just updating the property, but doing so by generating the value of the updated property directly from the given instruction, strictly following the guidelines. In the given example, the task is for a language model to generate a question, named 'inspired_query', based on a given context - the 'references'. The instruction stipulates that the generated question should delve into underlying concepts of a narrative captured in the references, and should emphasise the advantages of semantic search with vector embeddings over traditional methods. The generated question is the output, which is referred to as 'property_value' in the program. The model works by predicting the updated property value based on the provided property name, the references, and the given instruction. It then makes the response available as the output property_value. While working on this task, the model has been strictly instructed to only output the property value and nothing else.
#
# MODULE:
#
# TASK DEMO(S):
# Property Name: inspired_query
# References: inspired_question: None content: Chain of thought is a method commonly used to assist the language model with its reasoning capability. [AutoGPT](https://github.com/Significant-Gravitas/Auto-GPT) demonstrated how a model could run autonomously to complete various tasks without much human intervention. This was done by using chain of thought reasoning to break down tasks into intermediate steps. The program would then run continuously until all tasks were completed. Another cutting edge idea in this line of thinking is [Tree-of-Thoughts sampling](https://arxiv.org/abs/2305.10601).
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How can we leverage chain of thought reasoning and Tree-of-Thoughts sampling to revolutionize the way we approach semantic search in vector databases, enabling more accurate and context-aware recommendations?
#
#
# BASIC INSTRUCTION:
# Your task is to generate the value of a property by following the given instruction
# using the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!
#
# TIP: Keep the instruction clear and concise.
#
# PROPOSED INSTRUCTION: Based on the property name, provided references, and instructions, generate a suitable property value. Remember, the output should only be this property value and not include unnecessary explanations or comments. The product of this task should appear as an embodiment of the instruction, processed through the contextual lens of the references.
#
#
#
# PROPOSED INSTRUCTION: Based on the property name, provided references, and instructions, generate a suitable property value. Remember, the output should only be this property value and not include unnecessary explanations or comments. The product of this task should appear as an embodiment of the instruction, processed through the contextual lens of the references.
# PROGRAM DESCRIPTION: The program appears to be designed to solve the task of generating a new or updated property value given a property name, references, and instructions. The particular use case highlighted here indicates that the task focuses on generating "inspired queries" based on given content.
#
# The system prompts the user to provide a property name, some contexts (referred as 'references'), and instructions to modify or create a new property value. Within the contexts, there's existing content and the instruction sets a demand for constructing a deep, insightful question based on the given content. The question should not repeat the keywords from the content and should illuminate the advantages of semantic search with vector embeddings over traditional methods.
#
# In the examples, the 'instruction' and 'property_name' remain constant, while 'references' change for each case which is a snippet from different blog posts. The 'property_value' which the model generates is an insightful question derived from the 'references' in line with the 'instruction'.
#
# The program uses a language model, presumably a transformer-like model, to perform the task. The input to the model includes the property name, context information from the references, and the instructions on what should be done. The model then generates the output which is the required property value that adheres to the instruction given, which in this case, is a query.
#
# In the operational workflow, the model first initiates the `Program` class which contains a module to perform prediction based on the model. Within the `forward` function, the model predicts the property value using the provided `property_name`, `references`, and `instructions`. The returned value is then extracted and put out as a prediction, which is the desired property value generated in line with the given instruction.
# Warning: __init__ method not found in the program code.
# task_demos Property Name: inspired_query
# References: inspired_question: None content: ## Stronger together
# Of course, making Weaviate more reliable would be a lot harder without the great community around Weaviate. <br/>As it is often the case: *"You can't fix issues you didn't know you have"*. <!-- ![You can't fix issues you didn't know you have](./img/you-cant-fix.jpg) -->
#
# ### Thank you
# Thanks to many active members on Weaviate's Community Slack and through GitHub issues, we were able to identify, prioritize and fix many more issues than if we had to do it alone. > Together, we made Weaviate v1.14 <br/>the most stable release yet. ### Help us
# If at any point during your journey with Weaviate, you discover any bugs or you have feedback to share, please don't hesitate to reach out to us via:
# * [Weaviate's Slack](https://weaviate.io/slack) – you can join anytime
# * [GitHub issues for Weaviate Core](https://github.com/weaviate/weaviate/issues/new)
# * [GitHub issues for Weaviate's documentation](https://github.com/weaviate/weaviate-io/issues/new/choose)
#
# We have a little favour to ask.
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How do collaborative efforts in open-source communities like Weaviate's Community Slack and GitHub issues enable more effective issue detection, prioritization, and resolution, ultimately leading to improved semantic search capabilities through vector embeddings?
# Property Name: inspired_query
# References: inspired_question: None content: That makes Go a great compromise between both worlds. The syntax is straightforward, and the potential for memory-related bugs (such as memory leaks) is low. At the same time, it's not uncommon to have Go programs spend considerably less than 1% of their CPU time on GC-related activities. Given how little the average program is optimized for execution efficiency, trading in just 1% of execution time is a pretty good deal. After all, who wants to worry about freeing memory after it's been used?
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How do vector embeddings enable more accurate and relevant search results in complex data sets by capturing nuanced relationships between terms?
# Property Name: inspired_query
# References: inspired_question: None content: ---
# title: Generative Feedback Loops with LLMs for Vector Databases
# slug: generative-feedback-loops-with-LLMs
# authors: [connor]
# date: 2023-05-05
# image: ./img/hero.png
# tags: ['integrations', 'how-to']
# description: "An introduction to creating generative feedback loops with LLMs in Weaviate."
#
# ---
#
# ![Generative Feedback Loop with an LLM Visualization](./img/hero.png)
#
# <!-- truncate -->
#
# Large Language Models are heralding a new era in information technology. To better understand this revolution, it’s important to consider the historical context. The printing press significantly reduced the cost of reproducing information, while the internet cut out the middleman, making the distribution of information virtually free. [In Aggregation Theory](https://stratechery.com/2015/aggregation-theory/), Ben Thompson writes about how the free distribution of the internet allowed companies to modularize (or unbundle) services and focus on user experience. Ben states that “companies that win the user experience can generate a virtuous cycle where their ownership of consumers/users attracts suppliers which improves the user experience”.
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How do generative feedback loops with LLMs enable more accurate and context-aware recommendations in vector databases, ultimately leading to a better user experience?
#
#
#
#
# Use the information below to learn about a task that we are trying to solve using calls to an LM, then generate a new instruction that will be used to prompt a Language Model to better solve the task.
#
# ---
#
# Follow the following format.
#
# DATASET SUMMARY: A description of the dataset that we are using.
#
# PROGRAM CODE: Language model program designed to solve a particular task.
#
# PROGRAM DESCRIPTION: Summary of the task the program is designed to solve, and how it goes about solving it.
#
# MODULE: The module to create an instruction for.
#
# TASK DEMO(S): Example inputs/outputs of our module.
#
# BASIC INSTRUCTION: Basic instruction.
#
# TIP: A suggestion for how to go about generating the new instruction.
#
# PROPOSED INSTRUCTION: Propose an instruction that will be used to prompt a Language Model to perform this task.
#
# ---
#
# DATASET SUMMARY: The dataset concentrates on the technical aspects and unique functionalities of databases, particularly vector databases, including semantic search capabilities, Chain of Thought reasoning, and the influence of PQ compression on indexing algorithms. The task at hand is to generate a rich, non-verbatim query based on the given blog post content from Weaviate, a Vector Database company, to aid in creating discussion points or research questions for further study. It suggests an emphasis on semantic understanding and knowledge generation more than mere information retrieval.
#
# PROGRAM CODE:
# UpdateProperty(property_name, references, instruction -> property_value
#     instructions='Your task is to generate the value of a property by following the given instruction\nusing the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!'
#     property_name = Field(annotation=str required=True json_schema_extra={'desc': 'The name of the property that you should update.', '__dspy_field_type': 'input', 'prefix': 'Property Name:'})
#     references = Field(annotation=str required=True json_schema_extra={'desc': 'The name-value property pairs that you should refer to while updating the property.', '__dspy_field_type': 'input', 'prefix': 'References:'})
#     instruction = Field(annotation=str required=True json_schema_extra={'desc': 'The instruction that you should strictly follow while updating the property.', '__dspy_field_type': 'input', 'prefix': 'Instruction:'})
#     property_value = Field(annotation=UpdatedPropertyValue required=True json_schema_extra={'desc': 'VERY IMPORTANT!! ONLY OUTPUT THIS VALUE AND *NOTHING* ELSE!!!', '__dspy_field_type': 'output', 'prefix': 'Property Value:'})
# )
#
# class Program(dspy.Module):
#     def __init__(self) -> None:
#         self.predict = dspy.Predict(UpdateProperty)
#
#     def forward(self, property_name: str, references: str, instruction: str) -> str:
#         prediction = self.predict(
#             property_name=property_name, references=references, instruction=instruction
#         ).property_value
#         return dspy.Prediction(property_value=prediction)
#
#
# PROGRAM DESCRIPTION: The program appears to be designed to solve the task of generating a new or updated property value given a property name, references, and instructions. The particular use case highlighted here indicates that the task focuses on generating "inspired queries" based on given content. The system prompts the user to provide a property name, some contexts (referred as 'references'), and instructions to modify or create a new property value. Within the contexts, there's existing content and the instruction sets a demand for constructing a deep, insightful question based on the given content. The question should not repeat the keywords from the content and should illuminate the advantages of semantic search with vector embeddings over traditional methods. In the examples, the 'instruction' and 'property_name' remain constant, while 'references' change for each case which is a snippet from different blog posts. The 'property_value' which the model generates is an insightful question derived from the 'references' in line with the 'instruction'. The program uses a language model, presumably a transformer-like model, to perform the task. The input to the model includes the property name, context information from the references, and the instructions on what should be done. The model then generates the output which is the required property value that adheres to the instruction given, which in this case, is a query. In the operational workflow, the model first initiates the `Program` class which contains a module to perform prediction based on the model. Within the `forward` function, the model predicts the property value using the provided `property_name`, `references`, and `instructions`. The returned value is then extracted and put out as a prediction, which is the desired property value generated in line with the given instruction.
#
# MODULE:
#
# TASK DEMO(S):
# Property Name: inspired_query
# References: inspired_question: None content: ## Stronger together
# Of course, making Weaviate more reliable would be a lot harder without the great community around Weaviate. <br/>As it is often the case: *"You can't fix issues you didn't know you have"*. <!-- ![You can't fix issues you didn't know you have](./img/you-cant-fix.jpg) -->
#
# ### Thank you
# Thanks to many active members on Weaviate's Community Slack and through GitHub issues, we were able to identify, prioritize and fix many more issues than if we had to do it alone. > Together, we made Weaviate v1.14 <br/>the most stable release yet. ### Help us
# If at any point during your journey with Weaviate, you discover any bugs or you have feedback to share, please don't hesitate to reach out to us via:
# * [Weaviate's Slack](https://weaviate.io/slack) – you can join anytime
# * [GitHub issues for Weaviate Core](https://github.com/weaviate/weaviate/issues/new)
# * [GitHub issues for Weaviate's documentation](https://github.com/weaviate/weaviate-io/issues/new/choose)
#
# We have a little favour to ask.
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How do collaborative efforts in open-source communities like Weaviate's Community Slack and GitHub issues enable more effective issue detection, prioritization, and resolution, ultimately leading to improved semantic search capabilities through vector embeddings?
# Property Name: inspired_query
# References: inspired_question: None content: That makes Go a great compromise between both worlds. The syntax is straightforward, and the potential for memory-related bugs (such as memory leaks) is low. At the same time, it's not uncommon to have Go programs spend considerably less than 1% of their CPU time on GC-related activities. Given how little the average program is optimized for execution efficiency, trading in just 1% of execution time is a pretty good deal. After all, who wants to worry about freeing memory after it's been used?
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How do vector embeddings enable more accurate and relevant search results in complex data sets by capturing nuanced relationships between terms?
# Property Name: inspired_query
# References: inspired_question: None content: ---
# title: Generative Feedback Loops with LLMs for Vector Databases
# slug: generative-feedback-loops-with-LLMs
# authors: [connor]
# date: 2023-05-05
# image: ./img/hero.png
# tags: ['integrations', 'how-to']
# description: "An introduction to creating generative feedback loops with LLMs in Weaviate."
#
# ---
#
# ![Generative Feedback Loop with an LLM Visualization](./img/hero.png)
#
# <!-- truncate -->
#
# Large Language Models are heralding a new era in information technology. To better understand this revolution, it’s important to consider the historical context. The printing press significantly reduced the cost of reproducing information, while the internet cut out the middleman, making the distribution of information virtually free. [In Aggregation Theory](https://stratechery.com/2015/aggregation-theory/), Ben Thompson writes about how the free distribution of the internet allowed companies to modularize (or unbundle) services and focus on user experience. Ben states that “companies that win the user experience can generate a virtuous cycle where their ownership of consumers/users attracts suppliers which improves the user experience”.
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How do generative feedback loops with LLMs enable more accurate and context-aware recommendations in vector databases, ultimately leading to a better user experience?
#
#
# BASIC INSTRUCTION:
# Your task is to generate the value of a property by following the given instruction
# using the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!
#
# TIP: Keep the instruction clear and concise.
#
# PROPOSED INSTRUCTION: Based on a given blog post snippet from Weaviate, your task is to generate a deep, insightful question as the property value that explores underlined concepts and opens up new dimensions beyond the provided information. VERY IMPORTANT!! The question should highlight the benefits of semantic search with vector embeddings over traditional methods like BM25 and explore related implications or applications without repeating keywords from the text. Ensure that you ONLY OUTPUT THIS QUESTION AND NOTHING ELSE.
#
#
#
# PROPOSED INSTRUCTION: Based on a given blog post snippet from Weaviate, your task is to generate a deep, insightful question as the property value that explores underlined concepts and opens up new dimensions beyond the provided information. VERY IMPORTANT!! The question should highlight the benefits of semantic search with vector embeddings over traditional methods like BM25 and explore related implications or applications without repeating keywords from the text. Ensure that you ONLY OUTPUT THIS QUESTION AND NOTHING ELSE.
# PROGRAM DESCRIPTION: The program seems to be designed to generate a new value for a given property based on a set of instructions and context provided in the form of other property-value pairs. The task seems to be geared towards generating intuitive questions based on provided information from a blog post published by a Vector Database company, Weaviate.
#
# The `UpdateProperty` function appears to accept three arguments: `property_name`, `references`, and `instruction`. The 'property_name' seems to be the name of the property that should be updated. The 'references' appear to consist of property-value pairs that provide the context for the update. The 'instruction' appears to guide the update process. The aim is to generate a 'property_value' that reflects the updated property value, based on the provided references and instructions.
#
# The `Program` class then uses a predictive model (`self.predict`) to generate a prediction for the new property value, using the provided property name, references, and instruction. The prediction is then returned.
#
# The provided examples reveal that this process effectively generates explorative questions about Weaviate's vector database technology, based on the context and guidance provided. It proposes thought-provoking questions that go beyond the given blog content, emphasizing on semantic search capabilities over traditional keyword-based methods, hence, the queries aim to explore related concepts, implications, and applications from a provided document. The goal is to create a rich and engaging discussion around the topic, stimulating deeper understanding and critical thinking.
# Warning: __init__ method not found in the program code.
# task_demos Property Name: inspired_query
# References: inspired_question: None content: If you want to learn how to configure Weaviate to use PQ refer to the docs [here](/developers/weaviate/config-refs/schema/vector-index#how-to-configure-hnsw). ## KMeans encoding results
#
# First, the PQ feature added to version 1.18 of Weaviate is assessed in the sections below. To check performance and distortion, we compared our implementation to [NanoPQ](https://github.com/matsui528/nanopq) and we observed similar results. The main idea behind running these experiments is to explore how PQ compression would affect our current indexing algorithms. The experiments consist of fitting the Product Quantizer on some datasets and then calculating the recall by applying brute force search on the compressed vectors.
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How can I leverage Weaviate's Product Quantizer to enhance the performance and scalability of my semantic search application by compressing high-dimensional vectors while maintaining recall and precision?
# Property Name: inspired_query
# References: inspired_question: None content: By emphasizing the use of real-time information stored in Weaviate, we continuously update the language model with the latest data, bypassing the limitation of its encoded knowledge. Ultimately combining the peanut butter of factual information from the database with the jelly of LLM language understanding. ### Generate a description for each Listing
#
# import GenerativeFeedbackLoopsDescription from '/_includes/code/generative.feedback.loops.description.mdx';
#
# <GenerativeFeedbackLoopsDescription/>
#
# Now let's test a semantic search through the Listings, each vectorized with the respective LLM-generated `description`:
#
# import GenerativeFeedbackLoopsSearch from '/_includes/code/generative.feedback.loops.search.mdx';
#
# <GenerativeFeedbackLoopsSearch/>
#
# <details>
#   <summary>
#     OpenAI Generations
#   </summary>
#   <div>
#
# | Rank | Result |
# |------|--------|
# | 1    | This private room in the Bedford-Stuyvesant neighbourhood of Brooklyn is the perfect spot for a long-term stay. The space is clean and quiet, providing a peaceful retreat from the hustle and bustle of the city. With a minimum stay of 60 nights, you'll have plenty of time to explore all that Brooklyn has to offer.
# Instruction:
# Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information.
# VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: What is the potential for Weaviate's semantic search capabilities to revolutionize the way we approach information retrieval in complex domains such as natural language processing and machine learning, particularly when dealing with large-scale datasets that require nuanced understanding of context and relationships?
#
#
#
#
# Use the information below to learn about a task that we are trying to solve using calls to an LM, then generate a new instruction that will be used to prompt a Language Model to better solve the task.
#
# ---
#
# Follow the following format.
#
# DATASET SUMMARY: A description of the dataset that we are using.
#
# PROGRAM CODE: Language model program designed to solve a particular task.
#
# PROGRAM DESCRIPTION: Summary of the task the program is designed to solve, and how it goes about solving it.
#
# MODULE: The module to create an instruction for.
#
# TASK DEMO(S): Example inputs/outputs of our module.
#
# BASIC INSTRUCTION: Basic instruction.
#
# TIP: A suggestion for how to go about generating the new instruction.
#
# PROPOSED INSTRUCTION: Propose an instruction that will be used to prompt a Language Model to perform this task.
#
# ---
#
# DATASET SUMMARY: The dataset concentrates on the technical aspects and unique functionalities of databases, particularly vector databases, including semantic search capabilities, Chain of Thought reasoning, and the influence of PQ compression on indexing algorithms. The task at hand is to generate a rich, non-verbatim query based on the given blog post content from Weaviate, a Vector Database company, to aid in creating discussion points or research questions for further study. It suggests an emphasis on semantic understanding and knowledge generation more than mere information retrieval.
#
# PROGRAM CODE:
# UpdateProperty(property_name, references, instruction -> property_value
#     instructions='Your task is to generate the value of a property by following the given instruction\nusing the provided name-value property references as context. VERY IMPORTANT!! IT IS EXTREMELY IMPORTANT THAT YOU ONLY OUTPUT THIS VALUE AND NOTHING ELSE!!! PLEASE DO NOT BEGIN THE RESPONSE WITH SOMETHING LIKE "Sure, I can help you with that!" OR AFTER THE RESPONSE WRITE AN EXPLANATION OF WHY YOU RESPONDED WITH THIS VALUE. ONLY OUTPUT THE PROPERTY VALUE!!'
#     property_name = Field(annotation=str required=True json_schema_extra={'desc': 'The name of the property that you should update.', '__dspy_field_type': 'input', 'prefix': 'Property Name:'})
#     references = Field(annotation=str required=True json_schema_extra={'desc': 'The name-value property pairs that you should refer to while updating the property.', '__dspy_field_type': 'input', 'prefix': 'References:'})
#     instruction = Field(annotation=str required=True json_schema_extra={'desc': 'The instruction that you should strictly follow while updating the property.', '__dspy_field_type': 'input', 'prefix': 'Instruction:'})
#     property_value = Field(annotation=UpdatedPropertyValue required=True json_schema_extra={'desc': 'VERY IMPORTANT!! ONLY OUTPUT THIS VALUE AND *NOTHING* ELSE!!!', '__dspy_field_type': 'output', 'prefix': 'Property Value:'})
# )
#
# class Program(dspy.Module):
#     def __init__(self) -> None:
#         self.predict = dspy.Predict(UpdateProperty)
#
#     def forward(self, property_name: str, references: str, instruction: str) -> str:
#         prediction = self.predict(
#             property_name=property_name, references=references, instruction=instruction
#         ).property_value
#         return dspy.Prediction(property_value=prediction)
#
#
# ...
# FULL TRACE
# Average Metric: 0.75 / 1  (75.0): 100%|███████████| 1/1 [00:07<00:00,  7.65s/it]
# [I 2024-06-27 08:35:22,259] Trial 3 finished with value: 118.33 and parameters: {'0_predictor_instruction': 2}. Best is trial 2 with value: 339.17.
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can the collective intelligence and collaborative problem-solving capabilities of Weaviate's community be leveraged to develop more effective semantic search strategies that not only improve the reliability of vector-based databases but also unlock new insights and relationships between seemingly unrelated concepts?
# Rating: 0
#
#
#
#
#
#
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can the collective intelligence and collaborative problem-solving capabilities of Weaviate's community be leveraged to develop more effective semantic search strategies that not only improve the reliability of vector-based databases but also unlock new insights and relationships between seemingly unrelated concepts?
# Rating: 0
#
#
#
# ...
# Score 118.33
# CANDIDATE PROGRAM:
# Predictor 0
# i: Generate a question based on the provided content, which delves into deeper concepts and new dimensions relevant to Vector Databases and their features. Your question should address, but not repeat, the main points of the content in order to stimulate further research or discussion. The question should also underscore the advantages of semantic search with vector embeddings over traditional methods. Please ensure that only the question is returned as output, without any leading sentences or trailing commentary.
# p: Property Value:
#
#
# ...
# Average Metric: 17.83333333333333 / 10  (178.3): 100%|█| 10/10 [01:07<00:00,  6.
# FULL TRACE
# Average Metric: 0.75 / 1  (75.0): 100%|███████████| 1/1 [00:07<00:00,  7.06s/it]
# [I 2024-06-27 08:36:36,671] Trial 4 finished with value: 178.33 and parameters: {'0_predictor_instruction': 8}. Best is trial 2 with value: 339.17.
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can the integration of graph-based reasoning and vector embeddings in a Vector Database like Weaviate enable more accurate and context-aware recommendations for users, ultimately enhancing the overall search experience?
# Rating: 0
#
#
#
#
#
#
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can the integration of graph-based reasoning and vector embeddings in a Vector Database like Weaviate enable more accurate and context-aware recommendations for users, ultimately enhancing the overall search experience?
# Rating: 0
#
#
#
# ...
# Score 178.33
# CANDIDATE PROGRAM:
# Predictor 0
# i: Based on the given property name, reference properties, and provided instructions, your goal is to generate the new innovative query. Utilize the references as your brainstorming material and stringently follow the instruction to extract and embed the proper understanding. Your query should mainly highlight the superiority of semantic search with vector embeddings over the traditional search methods. REMEMBER!! Your response should ONLY be the generated query and NO additional information or explanations.
# p: Property Value:
#
#
# ...
# Average Metric: 33.91666666666667 / 10  (339.2): 100%|█| 10/10 [01:07<00:00,  6.
# FULL TRACE
# Average Metric: 0.16666666666666666 / 1  (16.7): 100%|█| 1/1 [00:07<00:00,  7.50
# [I 2024-06-27 08:37:51,482] Trial 5 finished with value: 339.17 and parameters: {'0_predictor_instruction': 6}. Best is trial 2 with value: 339.17.
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How do semantic search algorithms leveraging vector embeddings outperform traditional keyword-based approaches in identifying nuanced relationships between community-driven bug reports and subsequent software releases, ultimately leading to more reliable and stable products?
# Rating: 0
#
#
#
#
#
#
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How do semantic search algorithms leveraging vector embeddings outperform traditional keyword-based approaches in identifying nuanced relationships between community-driven bug reports and subsequent software releases, ultimately leading to more reliable and stable products?
# Rating: 0
#
#
#
# ...
# Score 339.17
# CANDIDATE PROGRAM:
# Predictor 0
# i: Based on the information from the Weaviate blog post and its content, generate a unique, compelling query that brings attention to the semantic search capabilities of vector databases. Make sure your question highlights the advantages of these capabilities over traditional methods, and explores new related concepts and applications. Remember, it is crucial that you generate ONLY the query and nothing else. Do not rephrase or directly repeat keywords from the source document.
# p: Property Value:
#
#
# ...
# Average Metric: 35.416666666666664 / 10  (354.2): 100%|█| 10/10 [01:13<00:00,  7
# FULL TRACE
# Average Metric: 0.75 / 1  (75.0): 100%|███████████| 1/1 [00:07<00:00,  7.14s/it]
# [I 2024-06-27 08:39:11,867] Trial 6 finished with value: 354.17 and parameters: {'0_predictor_instruction': 4}. Best is trial 6 with value: 354.17.
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can I leverage Weaviate's semantic search capabilities to identify and connect seemingly unrelated ideas across vast datasets, ultimately uncovering novel insights and relationships that would remain hidden with traditional keyword-based approaches?
# Rating: 0
#
#
#
#
#
#
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can I leverage Weaviate's semantic search capabilities to identify and connect seemingly unrelated ideas across vast datasets, ultimately uncovering novel insights and relationships that would remain hidden with traditional keyword-based approaches?
# Rating: 0
#
#
#
# ...
# Score 354.17
# CANDIDATE PROGRAM:
# Predictor 0
# i: Based on the property name, provided references, and instructions, generate a suitable property value. Remember, the output should only be this property value and not include unnecessary explanations or comments. The product of this task should appear as an embodiment of the instruction, processed through the contextual lens of the references.
# p: Property Value:
#
#
# ...
# Average Metric: 9.5 / 10  (95.0): 100%|█████████| 10/10 [01:03<00:00,  6.39s/it]
# FULL TRACE
# Average Metric: 0.75 / 1  (75.0): 100%|███████████| 1/1 [00:06<00:00,  6.76s/it]
# [I 2024-06-27 08:40:22,538] Trial 7 finished with value: 95.0 and parameters: {'0_predictor_instruction': 5}. Best is trial 6 with value: 354.17.
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can collaborative filtering and knowledge graph embeddings enhance the reliability of a vector database by leveraging collective intelligence and uncovering hidden relationships between entities?
# Rating: 0
#
#
#
#
#
#
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can collaborative filtering and knowledge graph embeddings enhance the reliability of a vector database by leveraging collective intelligence and uncovering hidden relationships between entities?
# Rating: 0
#
#
#
# ...
# Score 95.0
# CANDIDATE PROGRAM:
# Predictor 0
# i: Given the blog post snippet from Weaviate, generate a question that explores a deeper comprehension of the presented concepts and extends the discussion beyond the information provided. The question should underline the advantages of semantic search with vector embeddings, differ from traditional keyword-based methods, and must not directly echo any keywords from the snippet. This value must only be the question and contain no other information or form of address.
# p: Property Value:
#
#
# ...
# Average Metric: 21.666666666666668 / 10  (216.7): 100%|█| 10/10 [01:07<00:00,  6
# FULL TRACE
# Average Metric: 0.75 / 1  (75.0): 100%|███████████| 1/1 [00:07<00:00,  7.18s/it]
# [I 2024-06-27 08:41:37,240] Trial 8 finished with value: 216.67 and parameters: {'0_predictor_instruction': 3}. Best is trial 6 with value: 354.17.
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How do the collaborative efforts and collective knowledge of a community contribute to the development of more accurate and reliable semantic search models, ultimately enhancing the overall performance and value of vector-based databases like Weaviate?
# Rating: 0
#
#
#
#
#
#
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How do the collaborative efforts and collective knowledge of a community contribute to the development of more accurate and reliable semantic search models, ultimately enhancing the overall performance and value of vector-based databases like Weaviate?
# Rating: 0
#
#
#
# ...
# Score 216.67
# CANDIDATE PROGRAM:
# Predictor 0
# i: Generate a question based on the provided content, which delves into deeper concepts and new dimensions relevant to Vector Databases and their features. Your question should address, but not repeat, the main points of the content in order to stimulate further research or discussion. The question should also underscore the advantages of semantic search with vector embeddings over traditional methods. Please ensure that only the question is returned as output, without any leading sentences or trailing commentary.
# p: Property Value:
#
#
# ...
# Average Metric: 17.83333333333333 / 10  (178.3): 100%|█| 10/10 [01:07<00:00,  6.
# FULL TRACE
# Average Metric: 0.75 / 1  (75.0): 100%|███████████| 1/1 [00:07<00:00,  7.10s/it]
# [I 2024-06-27 08:42:51,612] Trial 9 finished with value: 178.33 and parameters: {'0_predictor_instruction': 8}. Best is trial 6 with value: 354.17.
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can the integration of graph-based reasoning and vector embeddings in a Vector Database like Weaviate enable more accurate and context-aware recommendations for users, ultimately enhancing the overall search experience?
# Rating: 0
#
#
#
#
#
#
# It is extremely important that the response only contains the `property_value` and no meta information or reflections about the assignment. Please output whether or not the `property_value` does this on a integer valued scale of 0 to 1.
#
# ---
#
# Follow the following format.
#
# Property Value: The response from the system containing the property value.
# Rating: An integer rating of either 0 or 1. IMPORTANT!! ONLY OUTPUT THE RATING!! (Respond with a single int value)
#
# ---
#
# Property Value: How can the integration of graph-based reasoning and vector embeddings in a Vector Database like Weaviate enable more accurate and context-aware recommendations for users, ultimately enhancing the overall search experience?
# Rating: 0
#
#
#
# ...
# Score 178.33

# %%
uuid = random.choice(blog_chunk_uuids)
obj = blogs.query.fetch_object_by_id(uuid)
references = " ".join(f"{k}: {v}" for k, v in obj.properties.items())

'''
Although the context manager is unnecessary for this notebook,
-- I left it there to remind people that you might have
-- set llama3 or another model as the default. So be careful if you
-- optimized the prompt for mistral, qwen, or what have you and then
-- are testing with a different model.
'''

with dspy.context(lm=llama3_ollama):
    print(MIPRO_compiled_GFL(
        property_name=property_name,
        instruction=instruction,
        references=references
    ))
# Out:
# Prediction(
#     property_value='How do multimodal embedding models enable more accurate and comprehensive knowledge retrieval in complex domains by leveraging the synergies between different sensory inputs?'
# )

# %%
llama3_ollama.inspect_history(n=1)
# Out:
# Based on the property name, provided references, and instructions, generate a suitable property value. Remember, the output should only be this property value and not include unnecessary explanations or comments. The product of this task should appear as an embodiment of the instruction, processed through the contextual lens of the references.
#
# ---
#
# Follow the following format.
#
# Property Name: The name of the property that you should update.
#
# References: The name-value property pairs that you should refer to while updating the property.
#
# Instruction: The instruction that you should strictly follow while updating the property.
#
# Property Value: VERY IMPORTANT!! ONLY OUTPUT THIS VALUE AND *NOTHING* ELSE!!!
#
# ---
#
# Property Name: inspired_query
#
# References: inspired_question: None content: --- title: Multimodal Embedding Models slug: multimodal-models authors: zain date: 2023-06-27 image: ./img/hero.png tags: ['concepts'] description: "ML Models that can see, read, hear and more!" --- ![Multimodal Models](./img/hero.png) <!-- truncate --> ## The Multisensory Nature of Human Learning Humans have a remarkable ability to learn and build world models through the integration of multiple sensory inputs. Our combination of senses work synergistically to provide us with rich and diverse information about our environment. By combining and interpreting these sensory inputs, we are able to form a coherent understanding of the world, make predictions, and acquire new knowledge very efficiently. The process of learning through multi-sensory inputs begins from the early stages of human development. Infants explore the world through their senses, touching, tasting, listening, and observing objects and people around them.
#
# Instruction: Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information. VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.
#
# Property Value: How do multimodal embedding models enable more accurate and comprehensive knowledge retrieval in complex domains by leveraging the synergies between different sensory inputs?
# '\n\n\nBased on the property name, provided references, and instructions, generate a suitable property value. Remember, the output should only be this property value and not include unnecessary explanations or comments. The product of this task should appear as an embodiment of the instruction, processed through the contextual lens of the references.\n\n---\n\nFollow the following format.\n\nProperty Name: The name of the property that you should update.\n\nReferences: The name-value property pairs that you should refer to while updating the property.\n\nInstruction: The instruction that you should strictly follow while updating the property.\n\nProperty Value: VERY IMPORTANT!! ONLY OUTPUT THIS VALUE AND *NOTHING* ELSE!!!\n\n---\n\nProperty Name: inspired_query\n\nReferences: inspired_question: None content: --- title: Multimodal Embedding Models slug: multimodal-models authors: zain date: 2023-06-27 image: ./img/hero.png tags: [\'concepts\'] description: "ML Models that can see, read, hear and more!" --- ![Multimodal Models](./img/hero.png) <!-- truncate --> ## The Multisensory Nature of Human Learning Humans have a remarkable ability to learn and build world models through the integration of multiple sensory inputs. Our combination of senses work synergistically to provide us with rich and diverse information about our environment. By combining and interpreting these sensory inputs, we are able to form a coherent understanding of the world, make predictions, and acquire new knowledge very efficiently. The process of learning through multi-sensory inputs begins from the early stages of human development. Infants explore the world through their senses, touching, tasting, listening, and observing objects and people around them.\n\nInstruction: Given a snippet from a blog post published by Weaviate, a Vector Database company, construct a question that delves deeply into the underlying concepts and explores new dimensions beyond the provided information. VERY IMPORTANT!! These queries should emphasize the advantages of semantic search with vector embeddings over traditional keyword-based methods like BM25. Ensure that the query explores related concepts, implications, or applications without directly repeating any keywords from the source document.\n\nProperty Value:\x1b How do multimodal embedding models enable more accurate and comprehensive knowledge retrieval in complex domains by leveraging the synergies between different sensory inputs?\x1b\n\n\n'
