# %% [markdown]
# # Semantic Chunking with Generative Feedback Loops
#
# This short tutorial illustrates how Generative Feedback Loops can help you with data ingestion and ETL workloads when developing with Weaviate. We show this particularly with the example of loading code repositories into Weaviate. We note the general concepts extend to applications such as PDFs, emails, and other media options, as well as more technical details such as RDBMS or Knowledge Graph to Vector Database integrations.
#
# Here are some helpful additional resources for learning about Generative Feedback Loops and Weaviate:
#
# - Learn more about Generative Feedback Loops with Bob van Luijt [here](https://www.youtube.com/watch?v=1RALju6ZJz0)!
#
# - Generative Feedback Loops notebooks on [Weaviate Recipes](https://github.com/weaviate/recipes/tree/main/weaviate-features/generative-feedback-loops)!
#
# - Weaviate Blog Post: [Generating Blog Posts with DSPy](https://weaviate.io/blog/hurricane-generative-feedback-loops)!
#
# ![Alt text](GFL.png)
#
# Generative Feedback Loops (GFLs) describe the co-evolution of data and AI models throughout the lifecycle of an AI application.
#
# GFLs capture the continuous exchange of feedback between data and AI models, where AI models enhance datasets by updating or creating data objects, and where data shapes AI models by providing learning signals for specific domains or tasks.
#
# ## Chapters
#
# ### 1. DSPy Setup
#
# Test connections to Weaviate, OpenAI, Anthropic, Gemini, Cohere, and Ollama.
#
# ### 2. Generative Feedback Loops with DSPy TypedPredictors
#
# Write a short summary of the file and ingest into Weaviate by chunking the code files and summarizing the code chunks.
#
# ### 3. Load Code Repositoy from Disk into Python Runtime Memory
#
# Load the DSPy code repository from disk and into the the Python runtime memory.
#
# ### 4. Import to Weaviate!
#
# Ingesting the DSPy Code Base into Weaviate with Generative Feedback Loops!

# %% [markdown]
# # 1. DSPy Setup
#
# Import DSPy and connect it to popular LLMs.

# %%
import dspy
import openai

openai.api_key = "sk-foobar"
CLAUDE_API_KEY = "sk-foobar"
cohere_api_key = "foobar"

# Start Llama 3.1 on your laptop with Ollama using!
'''bash
ollama run llama3.1
'''

gpt4 = dspy.OpenAI(model="gpt-4o", max_tokens=4_000, model_type="chat")
claude_opus = dspy.Claude(model="claude-3-opus-20240229", api_key=CLAUDE_API_KEY)
command_r_plus = dspy.Cohere(model="command-r-plus", max_tokens=4000, api_key=cohere_api_key)
ollama_llama3 = dspy.OllamaLocal(model="llama3.1")

lms = [
    {"name": "GPT-4", "lm": gpt4},
    {"name": "Claude Opus", "lm": claude_opus},
    {"name": "Command R+", "lm": command_r_plus},
    {"name": "Llama 3.1", "lm": ollama_llama3}
]

dspy.settings.configure(lm=gpt4)

connection_prompt = "Please say something interesting about Database Systems intended to impress me with your intelligence."

print(f"\033[36mTesting the prompt:\n\033[91m\n{connection_prompt}\n")

for lm_dict in lms:
    lm, name = lm_dict["lm"], lm_dict["name"]
    with dspy.context(lm=lm):
        print(f"\033[92mResult for {name}\n")
        print(f"\033[0m{lm(connection_prompt)[0]}\n")
# Out:
# /Users/cshorten/Library/Caches/pypoetry/virtualenvs/weaviate-agents-8ZuJxa4C-py3.10/lib/python3.10/site-packages/pydantic/_internal/_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# Testing the prompt:
#
# Please say something interesting about Database Systems intended to impress me with your intelligence.
#
# Result for GPT-4
#
# Certainly! One of the most fascinating aspects of modern database systems is their ability to handle distributed transactions across multiple nodes in a network while ensuring ACID (Atomicity, Consistency, Isolation, Durability) properties. This is particularly impressive given the challenges posed by the CAP theorem, which states that a distributed data store can only provide two out of the following three guarantees simultaneously: Consistency, Availability, and Partition Tolerance.
#
# To navigate this, advanced database systems like Google Spanner employ innovative techniques such as TrueTime, a globally synchronized clock, to achieve external consistency. This allows Spanner to provide strong consistency guarantees across geographically distributed data centers, which is a remarkable feat. TrueTime leverages GPS and atomic clocks to ensure that the timestamps used in transactions are accurate to within a few milliseconds, enabling the system to maintain a consistent state even in the presence of network partitions.
#
# This blend of distributed systems theory, cutting-edge hardware, and sophisticated algorithms exemplifies the complexity and ingenuity involved in modern database systems, making them a cornerstone of today's data-driven world.
#
# Result for Claude Opus
#
# Certainly! Let me share an interesting aspect of database systems that highlights their importance and complexity.
#
# Database systems are not only crucial for storing and managing vast amounts of data efficiently but also play a vital role in ensuring data integrity and consistency through the use of ACID properties. ACID stands for Atomicity, Consistency, Isolation, and Durability, which are essential characteristics of a reliable database transaction.
#
# Atomicity ensures that a transaction is treated as a single, indivisible unit of work. It means that either all the operations within a transaction are completed successfully, or none of them are applied, leaving the database in a consistent state.
#
# Consistency guarantees that a transaction brings the database from one valid state to another. It maintains the integrity of data by enforcing predefined rules, constraints, and relationships.
#
# Isolation allows multiple transactions to execute concurrently without interfering with each other. It provides the illusion that each transaction is running in isolation, preventing inconsistencies caused by interleaved operations.
#
# Durability ensures that once a transaction is committed, its effects are permanent and survive system failures. The changes made by a transaction are persistently stored and can be recovered even in the event of a system crash.
#
# Implementing ACID properties in a database system is a complex task, especially when dealing with high concurrency and large-scale data. Database management systems employ various techniques such as locking mechanisms, versioning, and write-ahead logging to achieve ACID compliance while maintaining performance and scalability.
#
# The ability of database systems to provide ACID properties while handling massive amounts of data and concurrent access is a testament to their sophistication and the ingenuity of database researchers and developers. It enables businesses and organizations to rely on the integrity and reliability of their data, which is critical for decision-making, regulatory compliance, and overall operational efficiency.
#
# Result for Command R+
#
# Database systems form the backbone of modern information management and are integral to almost every aspect of our digital lives. At their core, they serve as structured repositories of data, but their true power lies in their ability to provide efficient, secure, and reliable access to this data, enabling a myriad of applications and services that we rely on daily.
#
# One of the key concepts that underpins the intelligence and adaptability of database systems is the ACID properties - Atomicity, Consistency, Isolation, and Durability. These properties ensure that database transactions are processed reliably and predictably, maintaining data integrity even in complex and concurrent environments. This is crucial when you consider the vast amount of concurrent operations occurring in systems like online banking or e-commerce platforms, where data accuracy and consistency are paramount.
#
# Furthermore, modern database systems go beyond mere data storage and retrieval. They incorporate advanced features such as data warehousing, data mining, and machine learning capabilities. For instance, through the use of sophisticated algorithms, database systems can now identify patterns, make predictions, and provide insights, essentially turning raw data into valuable information. This not only helps businesses make data-driven decisions but also empowers scientists, researchers, and policymakers to address complex problems and uncover new knowledge.
#
# The evolution of database systems has also led to the development of distributed databases, which address the challenges of scalability, fault tolerance, and geographic distribution. By distributing data across multiple nodes or even multiple data centers, these systems can handle enormous data volumes and provide high availability, ensuring that services remain accessible even in the face of hardware failures or natural disasters. This distributed nature also enables global-scale applications, allowing users around the world to access data with minimal latency.
#
# Additionally, database systems have had to adapt to the changing landscape of data itself. With the advent of big data, we now deal with diverse data types, including unstructured data like text documents, images, and sensor data. NoSQL databases, for example, provide flexible schemas that can accommodate these varied data formats, allowing for the efficient storage and retrieval of non-traditional data types. This flexibility has been instrumental in fields like genomics, natural language processing, and the Internet of Things, where the ability to handle unstructured data is essential.
#
# Lastly, database systems play a pivotal role in data security and privacy, which are critical concerns in today's digital world. They employ encryption, access controls, and auditing mechanisms to safeguard sensitive information from unauthorized access, ensuring that only authorized users can view, modify, or delete data. With the ever-increasing number of cyber threats and data breaches, these security measures are vital to maintaining the trust and confidence of users and complying with legal and ethical standards for data protection.
#
# In conclusion, database systems are far more than just static repositories of data. They are dynamic, intelligent, and versatile systems that have revolutionized the way we manage, analyze, and leverage information. Their impact can be felt across industries, from healthcare and finance to e-commerce and social media, and their continued evolution will undoubtedly shape the future of data-driven technologies and innovations.
#
# Result for Llama 3.1
#
# Here's a tidbit that might just do the trick:
#
# Did you know that the concept of a database system was first proposed by Edgar F. Codd in 1970, and his ideas were initially met with skepticism? However, his paper "A Relational Model of Data for Large Shared Data Banks" introduced the notion of a self-describing, schema-based data storage system that could support complex queries and transactions.
#
# Codd's relational model was revolutionary because it abstracted away from physical storage details, allowing users to interact with data at a logical level. This led to the development of SQL (Structured Query Language), which became the de facto standard for querying relational databases.
#
# What's even more fascinating is that Codd's work built upon earlier ideas

# %% [markdown]
# # 2. DSPy Chunking Program
#
# We will now give the code files to a Large Language Model with instructions about the task of chunking in order to import data into Vector Databases.
#
# By leveraging Structured Outputs, the LLM will also output a summary of each chunk. These descriptions help developers quickly understand what purpose blocks of code serve. This is especially helpful when dealing with very large and rapdily changing codebases.

# %%
from typing import List
from pydantic import BaseModel

class ChunkWithSummary(BaseModel):
    chunk: str
    summary: str
    
class Chunker(dspy.Signature):
    """Your task is to divide a long document into coherent, semantic chunks of text. Each chunk should represent a complete thought or topic, typically ranging from one to three paragraphs in length. Follow these guidelines:
1. Focus on semantic coherence: Each chunk should contain text that revolves around a single main idea or closely related ideas.
2. Respect natural breaks: Use paragraph boundaries as a guide, but don't be bound by them if a topic continues across paragraphs.
3. Maintain context: Ensure that each chunk can be understood independently without losing crucial context.
4. Aim for consistency: Try to keep chunks relatively similar in length, but prioritize semantic completeness over strict length adherence.
5. Handle transitions: When encountering transition sentences between topics, include them with the most relevant chunk.
6. Consider document structure: Pay attention to headings, subheadings, and other structural elements that might indicate topic changes.
7. Adjust for content type: Be flexible based on the document's nature (e.g., academic papers might have longer chunks than news articles).

Your output should be a List of strings containing these semantic chunks, each representing a distinct portion of the original document while preserving its overall flow and meaning.
    """
    
    long_document: str = dspy.InputField()
    # file_summary: str = dspy.OutputField()
    chunks_with_summaries: List[ChunkWithSummary] = dspy.OutputField()
    
    
chunker = dspy.TypedPredictor(Chunker)

# %% [markdown]
# # 3. Load Code Repository into Memory
#
# Load the code files from a repo directory on disk and into memory.
#
# **Note:** When the Weaviate `gfl` API is released, you will be able to skip this step and directly apply Generative Feedback Loops on your data in Weaviate. Learn more [here](https://weaviate.io/gen-feedback-loops)!

# %%
import os

def traverse_directory(root_dir):
    file_contents = []
    text_extensions = {'.txt', '.py', '.md', '.json', '.csv', '.xml', '.html', '.css', '.js'}

    for dirpath, dirnames, filenames in os.walk(root_dir):
        print(f'Current directory: {dirpath}')
        
        if dirnames:
            print(f'\tSubdirectories: {", ".join(dirnames)}')

        for filename in filenames:
            file_path = os.path.join(dirpath, filename)
            print(f'\tFile: {file_path}')
            
            if any(filename.endswith(ext) for ext in text_extensions):
                try:
                    with open(file_path, 'r') as file:
                        content = file.read()
                        file_contents.append(content) # ToDo, add filename to Weaviate Schema & Import
                        print(f"\033[92mContent successfully read from {file_path}.\n\033[0m")
                except Exception as e:
                    print(f"An error occurred while reading {file_path}: {e}")
            else:
                print(f"\033[93mSkipped non-text file: {file_path}\033[0m")
    
    return file_contents

# %%
print("\033[36mLoading code from dspy...\033[0m\n")
dspy_code = traverse_directory("./dspy/dspy")

print("\033[36mLoading code from dsp...\033[0m\n")
dsp_code = traverse_directory("./dspy/dsp")

print("\033[36mLoading docs from docs...\033[0m\n")
dspy_docs = traverse_directory("./dspy/docs")
# Out:
# Loading code from dspy...
#
# Current directory: ./dspy/dspy
# 	Subdirectories: propose, experimental, signatures, datasets, utils, primitives, adapters, evaluate, predict, teleprompt, retrieve, functional
# 	File: ./dspy/dspy/__init__.py
# Content successfully read from ./dspy/dspy/__init__.py.
#
# Current directory: ./dspy/dspy/propose
# 	File: ./dspy/dspy/propose/__init__.py
# Content successfully read from ./dspy/dspy/propose/__init__.py.
#
# 	File: ./dspy/dspy/propose/dataset_summary_generator.py
# Content successfully read from ./dspy/dspy/propose/dataset_summary_generator.py.
#
# 	File: ./dspy/dspy/propose/propose_base.py
# Content successfully read from ./dspy/dspy/propose/propose_base.py.
#
# 	File: ./dspy/dspy/propose/instruction_proposal.py
# Content successfully read from ./dspy/dspy/propose/instruction_proposal.py.
#
# 	File: ./dspy/dspy/propose/utils.py
# Content successfully read from ./dspy/dspy/propose/utils.py.
#
# 	File: ./dspy/dspy/propose/grounded_proposer.py
# Content successfully read from ./dspy/dspy/propose/grounded_proposer.py.
#
# Current directory: ./dspy/dspy/experimental
# 	Subdirectories: synthesizer
# 	File: ./dspy/dspy/experimental/__init__.py
# Content successfully read from ./dspy/dspy/experimental/__init__.py.
#
# 	File: ./dspy/dspy/experimental/module_graph.py
# Content successfully read from ./dspy/dspy/experimental/module_graph.py.
#
# 	File: ./dspy/dspy/experimental/synthetic_data.py
# Content successfully read from ./dspy/dspy/experimental/synthetic_data.py.
#
# Current directory: ./dspy/dspy/experimental/synthesizer
# 	File: ./dspy/dspy/experimental/synthesizer/config.py
# Content successfully read from ./dspy/dspy/experimental/synthesizer/config.py.
#
# 	File: ./dspy/dspy/experimental/synthesizer/__init__.py
# Content successfully read from ./dspy/dspy/experimental/synthesizer/__init__.py.
#
# 	File: ./dspy/dspy/experimental/synthesizer/instruction_suffixes.py
# Content successfully read from ./dspy/dspy/experimental/synthesizer/instruction_suffixes.py.
#
# 	File: ./dspy/dspy/experimental/synthesizer/utils.py
# Content successfully read from ./dspy/dspy/experimental/synthesizer/utils.py.
#
# 	File: ./dspy/dspy/experimental/synthesizer/signatures.py
# Content successfully read from ./dspy/dspy/experimental/synthesizer/signatures.py.
#
# 	File: ./dspy/dspy/experimental/synthesizer/synthesizer.py
# Content successfully read from ./dspy/dspy/experimental/synthesizer/synthesizer.py.
#
# Current directory: ./dspy/dspy/signatures
# 	File: ./dspy/dspy/signatures/field.py
# Content successfully read from ./dspy/dspy/signatures/field.py.
#
# 	File: ./dspy/dspy/signatures/__init__.py
# Content successfully read from ./dspy/dspy/signatures/__init__.py.
#
# 	File: ./dspy/dspy/signatures/signature.py
# Content successfully read from ./dspy/dspy/signatures/signature.py.
#
# Current directory: ./dspy/dspy/datasets
# 	File: ./dspy/dspy/datasets/gsm8k.py
# Content successfully read from ./dspy/dspy/datasets/gsm8k.py.
#
# 	File: ./dspy/dspy/datasets/__init__.py
# Content successfully read from ./dspy/dspy/datasets/__init__.py.
#
# 	File: ./dspy/dspy/datasets/dataset.py
# Content successfully read from ./dspy/dspy/datasets/dataset.py.
#
# 	File: ./dspy/dspy/datasets/hotpotqa.py
# Content successfully read from ./dspy/dspy/datasets/hotpotqa.py.
#
# 	File: ./dspy/dspy/datasets/dataloader.py
# Content successfully read from ./dspy/dspy/datasets/dataloader.py.
#
# 	File: ./dspy/dspy/datasets/colors.py
# Content successfully read from ./dspy/dspy/datasets/colors.py.
#
# Current directory: ./dspy/dspy/utils
# 	File: ./dspy/dspy/utils/logging.py
# Content successfully read from ./dspy/dspy/utils/logging.py.
#
# 	File: ./dspy/dspy/utils/__init__.py
# Content successfully read from ./dspy/dspy/utils/__init__.py.
#
# 	File: ./dspy/dspy/utils/dummies.py
# Content successfully read from ./dspy/dspy/utils/dummies.py.
#
# Current directory: ./dspy/dspy/primitives
# 	File: ./dspy/dspy/primitives/box.py
# Content successfully read from ./dspy/dspy/primitives/box.py.
#
# 	File: ./dspy/dspy/primitives/__init__.py
# Content successfully read from ./dspy/dspy/primitives/__init__.py.
#
# 	File: ./dspy/dspy/primitives/assertions.py
# Content successfully read from ./dspy/dspy/primitives/assertions.py.
#
# 	File: ./dspy/dspy/primitives/prediction.py
# Content successfully read from ./dspy/dspy/primitives/prediction.py.
#
# 	File: ./dspy/dspy/primitives/example.py
# Content successfully read from ./dspy/dspy/primitives/example.py.
#
# 	File: ./dspy/dspy/primitives/program.py
# Content successfully read from ./dspy/dspy/primitives/program.py.
#
# 	File: ./dspy/dspy/primitives/python_interpreter.py
# Content successfully read from ./dspy/dspy/primitives/python_interpreter.py.
#
# 	File: ./dspy/dspy/primitives/module.py
# Content successfully read from ./dspy/dspy/primitives/module.py.
#
# Current directory: ./dspy/dspy/adapters
# 	File: ./dspy/dspy/adapters/chatml_adapter.py
# Content successfully read from ./dspy/dspy/adapters/chatml_adapter.py.
#
# 	File: ./dspy/dspy/adapters/basic_adapter.py
# Content successfully read from ./dspy/dspy/adapters/basic_adapter.py.
#
# 	File: ./dspy/dspy/adapters/__init__.py
# Content successfully read from ./dspy/dspy/adapters/__init__.py.
#
# 	File: ./dspy/dspy/adapters/llamachat_adapter.py
# Content successfully read from ./dspy/dspy/adapters/llamachat_adapter.py.
#
# 	File: ./dspy/dspy/adapters/vicuna_adapter.py
# Content successfully read from ./dspy/dspy/adapters/vicuna_adapter.py.
#
# Current directory: ./dspy/dspy/evaluate
# 	File: ./dspy/dspy/evaluate/metrics.py
# Content successfully read from ./dspy/dspy/evaluate/metrics.py.
#
# 	File: ./dspy/dspy/evaluate/auto_evaluation.py
# Content successfully read from ./dspy/dspy/evaluate/auto_evaluation.py.
#
# 	File: ./dspy/dspy/evaluate/__init__.py
# Content successfully read from ./dspy/dspy/evaluate/__init__.py.
#
# 	File: ./dspy/dspy/evaluate/evaluate.py
# Content successfully read from ./dspy/dspy/evaluate/evaluate.py.
#
# Current directory: ./dspy/dspy/predict
# 	Subdirectories: avatar
# 	File: ./dspy/dspy/predict/multi_chain_comparison.py
# Content successfully read from ./dspy/dspy/predict/multi_chain_comparison.py.
#
# 	File: ./dspy/dspy/predict/chain_of_thought_with_hint.py
# Content successfully read from ./dspy/dspy/predict/chain_of_thought_with_hint.py.
#
# 	File: ./dspy/dspy/predict/react.py
# Content successfully read from ./dspy/dspy/predict/react.py.
#
# 	File: ./dspy/dspy/predict/aggregation.py
# Content successfully read from ./dspy/dspy/predict/aggregation.py.
#
# 	File: ./dspy/dspy/predict/predict.py
# Content successfully read from ./dspy/dspy/predict/predict.py.
#
# 	File: ./dspy/dspy/predict/chain_of_thought.py
# Content successfully read from ./dspy/dspy/predict/chain_of_thought.py.
#
# 	File: ./dspy/dspy/predict/__init__.py
# Content successfully read from ./dspy/dspy/predict/__init__.py.
#
# 	File: ./dspy/dspy/predict/llamaindex.py
# Content successfully read from ./dspy/dspy/predict/llamaindex.py.
#
# 	File: ./dspy/dspy/predict/retry.py
# Content successfully read from ./dspy/dspy/predict/retry.py.
#
# 	File: ./dspy/dspy/predict/langchain.py
# Content successfully read from ./dspy/dspy/predict/langchain.py.
#
# 	File: ./dspy/dspy/predict/parameter.py
# Content successfully read from ./dspy/dspy/predict/parameter.py.
#
# 	File: ./dspy/dspy/predict/program_of_thought.py
# Content successfully read from ./dspy/dspy/predict/program_of_thought.py.
#
# 	File: ./dspy/dspy/predict/knn.py
# Content successfully read from ./dspy/dspy/predict/knn.py.
#
# Current directory: ./dspy/dspy/predict/avatar
# 	File: ./dspy/dspy/predict/avatar/models.py
# Content successfully read from ./dspy/dspy/predict/avatar/models.py.
#
# 	File: ./dspy/dspy/predict/avatar/__init__.py
# Content successfully read from ./dspy/dspy/predict/avatar/__init__.py.
#
# 	File: ./dspy/dspy/predict/avatar/avatar.py
# Content successfully read from ./dspy/dspy/predict/avatar/avatar.py.
#
# 	File: ./dspy/dspy/predict/avatar/signatures.py
# Content successfully read from ./dspy/dspy/predict/avatar/signatures.py.
#
# Current directory: ./dspy/dspy/teleprompt
# 	File: ./dspy/dspy/teleprompt/vanilla.py
# Content successfully read from ./dspy/dspy/teleprompt/vanilla.py.
#
# 	File: ./dspy/dspy/teleprompt/bootstrap.py
# Content successfully read from ./dspy/dspy/teleprompt/bootstrap.py.
#
# 	File: ./dspy/dspy/teleprompt/avatar_optimizer.py
# Content successfully read from ./dspy/dspy/teleprompt/avatar_optimizer.py.
#
# 	File: ./dspy/dspy/teleprompt/teleprompt_optuna.py
# Content successfully read from ./dspy/dspy/teleprompt/teleprompt_optuna.py.
#
# 	File: ./dspy/dspy/teleprompt/__init__.py
# Content successfully read from ./dspy/dspy/teleprompt/__init__.py.
#
# 	File: ./dspy/dspy/teleprompt/knn_fewshot.py
# Content successfully read from ./dspy/dspy/teleprompt/knn_fewshot.py.
#
# 	File: ./dspy/dspy/teleprompt/mipro_optimizer.py
# Content successfully read from ./dspy/dspy/teleprompt/mipro_optimizer.py.
#
# 	File: ./dspy/dspy/teleprompt/random_search.py
# Content successfully read from ./dspy/dspy/teleprompt/random_search.py.
#
# 	File: ./dspy/dspy/teleprompt/utils.py
# Content successfully read from ./dspy/dspy/teleprompt/utils.py.
#
# 	File: ./dspy/dspy/teleprompt/ensemble.py
# Content successfully read from ./dspy/dspy/teleprompt/ensemble.py.
#
# 	File: ./dspy/dspy/teleprompt/teleprompt.py
# Content successfully read from ./dspy/dspy/teleprompt/teleprompt.py.
#
# 	File: ./dspy/dspy/teleprompt/copro_optimizer.py
# Content successfully read from ./dspy/dspy/teleprompt/copro_optimizer.py.
#
# 	File: ./dspy/dspy/teleprompt/signature_opt.py
# Content successfully read from ./dspy/dspy/teleprompt/signature_opt.py.
#
# 	File: ./dspy/dspy/teleprompt/signature_opt_typed.py
# Content successfully read from ./dspy/dspy/teleprompt/signature_opt_typed.py.
#
# 	File: ./dspy/dspy/teleprompt/signature_opt_bayesian.py
# Content successfully read from ./dspy/dspy/teleprompt/signature_opt_bayesian.py.
#
# 	File: ./dspy/dspy/teleprompt/finetune.py
# Content successfully read from ./dspy/dspy/teleprompt/finetune.py.
#
# 	File: ./dspy/dspy/teleprompt/mipro_optimizer_v2.py
# Content successfully read from ./dspy/dspy/teleprompt/mipro_optimizer_v2.py.
#
# Current directory: ./dspy/dspy/retrieve
# 	File: ./dspy/dspy/retrieve/mongodb_atlas_rm.py
# Content successfully read from ./dspy/dspy/retrieve/mongodb_atlas_rm.py.
#
# 	File: ./dspy/dspy/retrieve/llama_index_rm.py
# Content successfully read from ./dspy/dspy/retrieve/llama_index_rm.py.
#
# 	File: ./dspy/dspy/retrieve/snowflake_rm.py
# Content successfully read from ./dspy/dspy/retrieve/snowflake_rm.py.
#
# 	File: ./dspy/dspy/retrieve/milvus_rm.py
# Content successfully read from ./dspy/dspy/retrieve/milvus_rm.py.
#
# 	File: ./dspy/dspy/retrieve/__init__.py
# Content successfully read from ./dspy/dspy/retrieve/__init__.py.
#
# 	File: ./dspy/dspy/retrieve/deeplake_rm.py
# Content successfully read from ./dspy/dspy/retrieve/deeplake_rm.py.
#
# 	File: ./dspy/dspy/retrieve/neo4j_rm.py
# Content successfully read from ./dspy/dspy/retrieve/neo4j_rm.py.
#
# 	File: ./dspy/dspy/retrieve/faiss_rm.py
# Content successfully read from ./dspy/dspy/retrieve/faiss_rm.py.
#
# 	File: ./dspy/dspy/retrieve/azureaisearch_rm.py
# Content successfully read from ./dspy/dspy/retrieve/azureaisearch_rm.py.
#
# 	File: ./dspy/dspy/retrieve/pinecone_rm.py
# Content successfully read from ./dspy/dspy/retrieve/pinecone_rm.py.
#
# 	File: ./dspy/dspy/retrieve/watson_discovery_rm.py
# Content successfully read from ./dspy/dspy/retrieve/watson_discovery_rm.py.
#
# 	File: ./dspy/dspy/retrieve/qdrant_rm.py
# Content successfully read from ./dspy/dspy/retrieve/qdrant_rm.py.
#
# 	File: ./dspy/dspy/retrieve/marqo_rm.py
# Content successfully read from ./dspy/dspy/retrieve/marqo_rm.py.
#
# 	File: ./dspy/dspy/retrieve/weaviate_rm.py
# Content successfully read from ./dspy/dspy/retrieve/weaviate_rm.py.
#
# 	File: ./dspy/dspy/retrieve/epsilla_rm.py
# Content successfully read from ./dspy/dspy/retrieve/epsilla_rm.py.
#
# 	File: ./dspy/dspy/retrieve/vectara_rm.py
# Content successfully read from ./dspy/dspy/retrieve/vectara_rm.py.
#
# 	File: ./dspy/dspy/retrieve/clarifai_rm.py
# Content successfully read from ./dspy/dspy/retrieve/clarifai_rm.py.
#
# 	File: ./dspy/dspy/retrieve/ragatouille_rm.py
# Content successfully read from ./dspy/dspy/retrieve/ragatouille_rm.py.
#
# 	File: ./dspy/dspy/retrieve/pgvector_rm.py
# Content successfully read from ./dspy/dspy/retrieve/pgvector_rm.py.
#
# 	File: ./dspy/dspy/retrieve/retrieve.py
# Content successfully read from ./dspy/dspy/retrieve/retrieve.py.
#
# 	File: ./dspy/dspy/retrieve/MyScaleRM.py
# Content successfully read from ./dspy/dspy/retrieve/MyScaleRM.py.
#
# 	File: ./dspy/dspy/retrieve/chromadb_rm.py
# Content successfully read from ./dspy/dspy/retrieve/chromadb_rm.py.
#
# 	File: ./dspy/dspy/retrieve/you_rm.py
# Content successfully read from ./dspy/dspy/retrieve/you_rm.py.
#
# 	File: ./dspy/dspy/retrieve/databricks_rm.py
# Content successfully read from ./dspy/dspy/retrieve/databricks_rm.py.
#
# Current directory: ./dspy/dspy/functional
# 	File: ./dspy/dspy/functional/__init__.py
# Content successfully read from ./dspy/dspy/functional/__init__.py.
#
# 	File: ./dspy/dspy/functional/functional.py
# Content successfully read from ./dspy/dspy/functional/functional.py.
#
# Loading code from dsp...
#
# Current directory: ./dspy/dsp
# 	Subdirectories: utils, primitives, adapters, evaluation, modules
# 	File: ./dspy/dsp/__init__.py
# Content successfully read from ./dspy/dsp/__init__.py.
#
# Current directory: ./dspy/dsp/utils
# 	File: ./dspy/dsp/utils/metrics.py
# Content successfully read from ./dspy/dsp/utils/metrics.py.
#
# 	File: ./dspy/dsp/utils/__init__.py
# Content successfully read from ./dspy/dsp/utils/__init__.py.
#
# 	File: ./dspy/dsp/utils/settings_v2.py
# Content successfully read from ./dspy/dsp/utils/settings_v2.py.
#
# 	File: ./dspy/dsp/utils/utils.py
# Content successfully read from ./dspy/dsp/utils/utils.py.
#
# 	File: ./dspy/dsp/utils/ann_utils.py
# Content successfully read from ./dspy/dsp/utils/ann_utils.py.
#
# 	File: ./dspy/dsp/utils/settings.py
# Content successfully read from ./dspy/dsp/utils/settings.py.
#
# 	File: ./dspy/dsp/utils/dpr.py
# Content successfully read from ./dspy/dsp/utils/dpr.py.
#
# Current directory: ./dspy/dsp/primitives
# 	File: ./dspy/dsp/primitives/demonstrate.py
# Content successfully read from ./dspy/dsp/primitives/demonstrate.py.
#
# 	File: ./dspy/dsp/primitives/compiler.py
# Content successfully read from ./dspy/dsp/primitives/compiler.py.
#
# 	File: ./dspy/dsp/primitives/primitives.py
# Content successfully read from ./dspy/dsp/primitives/primitives.py.
#
# 	File: ./dspy/dsp/primitives/predict.py
# Content successfully read from ./dspy/dsp/primitives/predict.py.
#
# 	File: ./dspy/dsp/primitives/__init__.py
# Content successfully read from ./dspy/dsp/primitives/__init__.py.
#
# 	File: ./dspy/dsp/primitives/inspect.py
# Content successfully read from ./dspy/dsp/primitives/inspect.py.
#
# 	File: ./dspy/dsp/primitives/search.py
# Content successfully read from ./dspy/dsp/primitives/search.py.
#
# Current directory: ./dspy/dsp/adapters
# 	File: ./dspy/dsp/adapters/__init__.py
# Content successfully read from ./dspy/dsp/adapters/__init__.py.
#
# 	File: ./dspy/dsp/adapters/utils.py
# Content successfully read from ./dspy/dsp/adapters/utils.py.
#
# 	File: ./dspy/dsp/adapters/base_template.py
# Content successfully read from ./dspy/dsp/adapters/base_template.py.
#
# 	File: ./dspy/dsp/adapters/template.py
# Content successfully read from ./dspy/dsp/adapters/template.py.
#
# 	File: ./dspy/dsp/adapters/experimental_adapter.py
# Content successfully read from ./dspy/dsp/adapters/experimental_adapter.py.
#
# Current directory: ./dspy/dsp/evaluation
# 	File: ./dspy/dsp/evaluation/__init__.py
# Content successfully read from ./dspy/dsp/evaluation/__init__.py.
#
# 	File: ./dspy/dsp/evaluation/utils.py
# Content successfully read from ./dspy/dsp/evaluation/utils.py.
#
# Current directory: ./dspy/dsp/modules
# 	Subdirectories: finetuning
# 	File: ./dspy/dsp/modules/gpt3.py
# Content successfully read from ./dspy/dsp/modules/gpt3.py.
#
# 	File: ./dspy/dsp/modules/premai.py
# Content successfully read from ./dspy/dsp/modules/premai.py.
#
# 	File: ./dspy/dsp/modules/mistral.py
# Content successfully read from ./dspy/dsp/modules/mistral.py.
#
# 	File: ./dspy/dsp/modules/sentence_vectorizer.py
# Content successfully read from ./dspy/dsp/modules/sentence_vectorizer.py.
#
# 	File: ./dspy/dsp/modules/sbert.py
# Content successfully read from ./dspy/dsp/modules/sbert.py.
#
# 	File: ./dspy/dsp/modules/dummy_lm.py
# Content successfully read from ./dspy/dsp/modules/dummy_lm.py.
#
# 	File: ./dspy/dsp/modules/aws_models.py
# Content successfully read from ./dspy/dsp/modules/aws_models.py.
#
# 	File: ./dspy/dsp/modules/aws_providers.py
# Content successfully read from ./dspy/dsp/modules/aws_providers.py.
#
# 	File: ./dspy/dsp/modules/azurecognitivesearch.py
# Content successfully read from ./dspy/dsp/modules/azurecognitivesearch.py.
#
# 	File: ./dspy/dsp/modules/multi_openai.py
# Content successfully read from ./dspy/dsp/modules/multi_openai.py.
#
# 	File: ./dspy/dsp/modules/__init__.py
# Content successfully read from ./dspy/dsp/modules/__init__.py.
#
# 	File: ./dspy/dsp/modules/cloudflare.py
# Content successfully read from ./dspy/dsp/modules/cloudflare.py.
#
# 	File: ./dspy/dsp/modules/google.py
# Content successfully read from ./dspy/dsp/modules/google.py.
#
# 	File: ./dspy/dsp/modules/you.py
# Content successfully read from ./dspy/dsp/modules/you.py.
#
# 	File: ./dspy/dsp/modules/llama.py
# Content successfully read from ./dspy/dsp/modules/llama.py.
#
# 	File: ./dspy/dsp/modules/groq_client.py
# Content successfully read from ./dspy/dsp/modules/groq_client.py.
#
# 	File: ./dspy/dsp/modules/azure_openai.py
# Content successfully read from ./dspy/dsp/modules/azure_openai.py.
#
# 	File: ./dspy/dsp/modules/hf_server.py
# Content successfully read from ./dspy/dsp/modules/hf_server.py.
#
# 	File: ./dspy/dsp/modules/cache_utils.py
# Content successfully read from ./dspy/dsp/modules/cache_utils.py.
#
# 	File: ./dspy/dsp/modules/snowflake.py
# Content successfully read from ./dspy/dsp/modules/snowflake.py.
#
# 	File: ./dspy/dsp/modules/anthropic.py
# Content successfully read from ./dspy/dsp/modules/anthropic.py.
#
# 	File: ./dspy/dsp/modules/lm.py
# Content successfully read from ./dspy/dsp/modules/lm.py.
#
# 	File: ./dspy/dsp/modules/colbertv2.py
# Content successfully read from ./dspy/dsp/modules/colbertv2.py.
#
# 	File: ./dspy/dsp/modules/watsonx.py
# Content successfully read from ./dspy/dsp/modules/watsonx.py.
#
# 	File: ./dspy/dsp/modules/databricks.py
# Content successfully read from ./dspy/dsp/modules/databricks.py.
#
# 	File: ./dspy/dsp/modules/tensorrt_llm.py
# Content successfully read from ./dspy/dsp/modules/tensorrt_llm.py.
#
# 	File: ./dspy/dsp/modules/clarifai.py
# Content successfully read from ./dspy/dsp/modules/clarifai.py.
#
# 	File: ./dspy/dsp/modules/hf_client.py
# Content successfully read from ./dspy/dsp/modules/hf_client.py.
#
# 	File: ./dspy/dsp/modules/cohere.py
# Content successfully read from ./dspy/dsp/modules/cohere.py.
#
# 	File: ./dspy/dsp/modules/pyserini.py
# Content successfully read from ./dspy/dsp/modules/pyserini.py.
#
# 	File: ./dspy/dsp/modules/ollama.py
# Content successfully read from ./dspy/dsp/modules/ollama.py.
#
# 	File: ./dspy/dsp/modules/hf.py
# Content successfully read from ./dspy/dsp/modules/hf.py.
#
# 	File: ./dspy/dsp/modules/googlevertexai.py
# Content successfully read from ./dspy/dsp/modules/googlevertexai.py.
#
# Current directory: ./dspy/dsp/modules/finetuning
# 	File: ./dspy/dsp/modules/finetuning/__init__.py
# Content successfully read from ./dspy/dsp/modules/finetuning/__init__.py.
#
# 	File: ./dspy/dsp/modules/finetuning/finetune_hf.py
# Content successfully read from ./dspy/dsp/modules/finetuning/finetune_hf.py.
#
# Loading docs from docs...
#
# Current directory: ./dspy/docs
# 	Subdirectories: images, docs, static, api, src
# 	File: ./dspy/docs/docusaurus.config.ts
# Skipped non-text file: ./dspy/docs/docusaurus.config.ts
# 	File: ./dspy/docs/sidebars.ts
# Skipped non-text file: ./dspy/docs/sidebars.ts
# 	File: ./dspy/docs/README.md
# Content successfully read from ./dspy/docs/README.md.
#
# 	File: ./dspy/docs/babel.config.js
# Content successfully read from ./dspy/docs/babel.config.js.
#
# 	File: ./dspy/docs/.gitignore
# Skipped non-text file: ./dspy/docs/.gitignore
# 	File: ./dspy/docs/package-lock.json
# Content successfully read from ./dspy/docs/package-lock.json.
#
# 	File: ./dspy/docs/package.json
# Content successfully read from ./dspy/docs/package.json.
#
# 	File: ./dspy/docs/tsconfig.json
# Content successfully read from ./dspy/docs/tsconfig.json.
#
# Current directory: ./dspy/docs/images
# 	File: ./dspy/docs/images/DSPy8.png
# Skipped non-text file: ./dspy/docs/images/DSPy8.png
# 	File: ./dspy/docs/images/DSPy_whitebg.png
# Skipped non-text file: ./dspy/docs/images/DSPy_whitebg.png
# 	File: ./dspy/docs/images/DSP-tasks.png
# Skipped non-text file: ./dspy/docs/images/DSP-tasks.png
# 	File: ./dspy/docs/images/DSP-example.png
# Skipped non-text file: ./dspy/docs/images/DSP-example.png
# 	File: ./dspy/docs/images/DSPy7.png
# Skipped non-text file: ./dspy/docs/images/DSPy7.png
# 	File: ./dspy/docs/images/DSPy-visualizer.png
# Skipped non-text file: ./dspy/docs/images/DSPy-visualizer.png
# Current directory: ./dspy/docs/docs
# 	Subdirectories: deep-dive, internal, quick-start, tutorials, building-blocks
# 	File: ./dspy/docs/docs/faqs.md
# Content successfully read from ./dspy/docs/docs/faqs.md.
#
# 	File: ./dspy/docs/docs/intro.md
# Content successfully read from ./dspy/docs/docs/intro.md.
#
# 	File: ./dspy/docs/docs/cheatsheet.md
# Content successfully read from ./dspy/docs/docs/cheatsheet.md.
#
# Current directory: ./dspy/docs/docs/deep-dive
# 	Subdirectories: typed_predictors, teleprompter, signature, retrieval_models_clients, data-handling, language_model_clients, modules
# 	File: ./dspy/docs/docs/deep-dive/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/_category_.json.
#
# Current directory: ./dspy/docs/docs/deep-dive/typed_predictors
# 	File: ./dspy/docs/docs/deep-dive/typed_predictors/understanding_predictors.md
# Content successfully read from ./dspy/docs/docs/deep-dive/typed_predictors/understanding_predictors.md.
#
# 	File: ./dspy/docs/docs/deep-dive/typed_predictors/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/typed_predictors/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/typed_predictors/functional_typed_predictors.md
# Content successfully read from ./dspy/docs/docs/deep-dive/typed_predictors/functional_typed_predictors.md.
#
# Current directory: ./dspy/docs/docs/deep-dive/teleprompter
# 	Subdirectories: img
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/teleprompter/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/bootstrap-fewshot.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/teleprompter/bootstrap-fewshot.mdx
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/signature-optimizer.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/teleprompter/signature-optimizer.mdx
# Current directory: ./dspy/docs/docs/deep-dive/teleprompter/img
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process_v2.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process_v2.png
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process_v3.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process_v3.png
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process_v4.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process_v4.png
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer.png
# 	File: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/teleprompter/img/signature_optimizer_process.png
# Current directory: ./dspy/docs/docs/deep-dive/signature
# 	Subdirectories: img
# 	File: ./dspy/docs/docs/deep-dive/signature/internal-signatures.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/signature/internal-signatures.mdx
# 	File: ./dspy/docs/docs/deep-dive/signature/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/signature/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/signature/understanding-signatures.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/signature/understanding-signatures.mdx
# 	File: ./dspy/docs/docs/deep-dive/signature/executing-signatures.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/signature/executing-signatures.mdx
# Current directory: ./dspy/docs/docs/deep-dive/signature/img
# 	File: ./dspy/docs/docs/deep-dive/signature/img/class_based_prompt_creation.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/signature/img/class_based_prompt_creation.png
# 	File: ./dspy/docs/docs/deep-dive/signature/img/dspy_signatures.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/signature/img/dspy_signatures.png
# 	File: ./dspy/docs/docs/deep-dive/signature/img/prompt_creation.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/signature/img/prompt_creation.png
# Current directory: ./dspy/docs/docs/deep-dive/retrieval_models_clients
# 	Subdirectories: img
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/ColBERTv2.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/ColBERTv2.mdx
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/ChromadbRM.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/ChromadbRM.mdx
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/custom-rm-client.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/custom-rm-client.mdx
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/retrieval_models_clients/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/QdrantRM.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/QdrantRM.mdx
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/WeaviateRM.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/WeaviateRM.mdx
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/Azure.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/Azure.mdx
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/MilvusRM.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/MilvusRM.mdx
# Current directory: ./dspy/docs/docs/deep-dive/retrieval_models_clients/img
# 	File: ./dspy/docs/docs/deep-dive/retrieval_models_clients/img/io_rm_module.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/retrieval_models_clients/img/io_rm_module.png
# Current directory: ./dspy/docs/docs/deep-dive/data-handling
# 	Subdirectories: img
# 	File: ./dspy/docs/docs/deep-dive/data-handling/examples.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/data-handling/examples.mdx
# 	File: ./dspy/docs/docs/deep-dive/data-handling/built-in-datasets.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/data-handling/built-in-datasets.mdx
# 	File: ./dspy/docs/docs/deep-dive/data-handling/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/data-handling/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/data-handling/loading-custom-data.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/data-handling/loading-custom-data.mdx
# Current directory: ./dspy/docs/docs/deep-dive/data-handling/img
# 	File: ./dspy/docs/docs/deep-dive/data-handling/img/data-loading.png
# Skipped non-text file: ./dspy/docs/docs/deep-dive/data-handling/img/data-loading.png
# Current directory: ./dspy/docs/docs/deep-dive/language_model_clients
# 	Subdirectories: local_models, remote_models
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/language_model_clients/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/custom-lm-client.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/custom-lm-client.mdx
# Current directory: ./dspy/docs/docs/deep-dive/language_model_clients/local_models
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/local_models/HFClientVLLM.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/local_models/HFClientVLLM.mdx
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/local_models/HFClientTGI.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/local_models/HFClientTGI.mdx
# Current directory: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/PremAI.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/PremAI.mdx
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/OpenAI.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/OpenAI.mdx
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/Anyscale.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/Anyscale.mdx
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/Together.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/Together.mdx
# 	File: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/Cohere.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/language_model_clients/remote_models/Cohere.mdx
# Current directory: ./dspy/docs/docs/deep-dive/modules
# 	File: ./dspy/docs/docs/deep-dive/modules/guide.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/modules/guide.mdx
# 	File: ./dspy/docs/docs/deep-dive/modules/retrieve.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/modules/retrieve.mdx
# 	File: ./dspy/docs/docs/deep-dive/modules/_category_.json
# Content successfully read from ./dspy/docs/docs/deep-dive/modules/_category_.json.
#
# 	File: ./dspy/docs/docs/deep-dive/modules/chain-of-thought-with-hint.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/modules/chain-of-thought-with-hint.mdx
# 	File: ./dspy/docs/docs/deep-dive/modules/react.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/modules/react.mdx
# 	File: ./dspy/docs/docs/deep-dive/modules/assertions.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/modules/assertions.mdx
# 	File: ./dspy/docs/docs/deep-dive/modules/program-of-thought.mdx
# Skipped non-text file: ./dspy/docs/docs/deep-dive/modules/program-of-thought.mdx
# Current directory: ./dspy/docs/docs/internal
# 	File: ./dspy/docs/docs/internal/build-and-release.md
# Content successfully read from ./dspy/docs/docs/internal/build-and-release.md.
#
# 	File: ./dspy/docs/docs/internal/release-checklist.md
# Content successfully read from ./dspy/docs/docs/internal/release-checklist.md.
#
# Current directory: ./dspy/docs/docs/quick-start
# 	File: ./dspy/docs/docs/quick-start/_category_.json
# Content successfully read from ./dspy/docs/docs/quick-start/_category_.json.
#
# 	File: ./dspy/docs/docs/quick-start/minimal-example.mdx
# Skipped non-text file: ./dspy/docs/docs/quick-start/minimal-example.mdx
# 	File: ./dspy/docs/docs/quick-start/installation.mdx
# Skipped non-text file: ./dspy/docs/docs/quick-start/installation.mdx
# Current directory: ./dspy/docs/docs/tutorials
# 	File: ./dspy/docs/docs/tutorials/other_tutorial.md
# Content successfully read from ./dspy/docs/docs/tutorials/other_tutorial.md.
#
# 	File: ./dspy/docs/docs/tutorials/simplified-baleen.md
# Content successfully read from ./dspy/docs/docs/tutorials/simplified-baleen.md.
#
# 	File: ./dspy/docs/docs/tutorials/examples.md
# Content successfully read from ./dspy/docs/docs/tutorials/examples.md.
#
# 	File: ./dspy/docs/docs/tutorials/rag.md
# Content successfully read from ./dspy/docs/docs/tutorials/rag.md.
#
# 	File: ./dspy/docs/docs/tutorials/_category_.json
# Content successfully read from ./dspy/docs/docs/tutorials/_category_.json.
#
# Current directory: ./dspy/docs/docs/building-blocks
# 	Subdirectories: figures
# 	File: ./dspy/docs/docs/building-blocks/1-language_models.md
# Content successfully read from ./dspy/docs/docs/building-blocks/1-language_models.md.
#
# 	File: ./dspy/docs/docs/building-blocks/8-typed_predictors.md
# Content successfully read from ./dspy/docs/docs/building-blocks/8-typed_predictors.md.
#
# 	File: ./dspy/docs/docs/building-blocks/_category_.json
# Content successfully read from ./dspy/docs/docs/building-blocks/_category_.json.
#
# 	File: ./dspy/docs/docs/building-blocks/solving_your_task.md
# Content successfully read from ./dspy/docs/docs/building-blocks/solving_your_task.md.
#
# 	File: ./dspy/docs/docs/building-blocks/7-assertions.md
# Content successfully read from ./dspy/docs/docs/building-blocks/7-assertions.md.
#
# 	File: ./dspy/docs/docs/building-blocks/6-optimizers.md
# Content successfully read from ./dspy/docs/docs/building-blocks/6-optimizers.md.
#
# 	File: ./dspy/docs/docs/building-blocks/5-metrics.md
# Content successfully read from ./dspy/docs/docs/building-blocks/5-metrics.md.
#
# 	File: ./dspy/docs/docs/building-blocks/3-modules.md
# Content successfully read from ./dspy/docs/docs/building-blocks/3-modules.md.
#
# 	File: ./dspy/docs/docs/building-blocks/2-signatures.md
# Content successfully read from ./dspy/docs/docs/building-blocks/2-signatures.md.
#
# 	File: ./dspy/docs/docs/building-blocks/4-data.md
# Content successfully read from ./dspy/docs/docs/building-blocks/4-data.md.
#
# Current directory: ./dspy/docs/docs/building-blocks/figures
# 	File: ./dspy/docs/docs/building-blocks/figures/teleprompter-classes.png
# Skipped non-text file: ./dspy/docs/docs/building-blocks/figures/teleprompter-classes.png
# Current directory: ./dspy/docs/static
# 	Subdirectories: img
# 	File: ./dspy/docs/static/.nojekyll
# Skipped non-text file: ./dspy/docs/static/.nojekyll
# Current directory: ./dspy/docs/static/img
# 	File: ./dspy/docs/static/img/undraw_docusaurus_mountain.svg
# Skipped non-text file: ./dspy/docs/static/img/undraw_docusaurus_mountain.svg
# 	File: ./dspy/docs/static/img/universal_compatibility.png
# Skipped non-text file: ./dspy/docs/static/img/universal_compatibility.png
# 	File: ./dspy/docs/static/img/modular.png
# Skipped non-text file: ./dspy/docs/static/img/modular.png
# 	File: ./dspy/docs/static/img/undraw_docusaurus_react.svg
# Skipped non-text file: ./dspy/docs/static/img/undraw_docusaurus_react.svg
# 	File: ./dspy/docs/static/img/logo.png
# Skipped non-text file: ./dspy/docs/static/img/logo.png
# 	File: ./dspy/docs/static/img/undraw_docusaurus_tree.svg
# Skipped non-text file: ./dspy/docs/static/img/undraw_docusaurus_tree.svg
# 	File: ./dspy/docs/static/img/dspy_logo.png
# Skipped non-text file: ./dspy/docs/static/img/dspy_logo.png
# 	File: ./dspy/docs/static/img/optimize.png
# Skipped non-text file: ./dspy/docs/static/img/optimize.png
# Current directory: ./dspy/docs/api
# 	Subdirectories: local_language_model_clients, optimizers, retrieval_model_clients, language_model_clients, modules, functional
# 	File: ./dspy/docs/api/intro.md
# Content successfully read from ./dspy/docs/api/intro.md.
#
# 	File: ./dspy/docs/api/assertions.md
# Content successfully read from ./dspy/docs/api/assertions.md.
#
# Current directory: ./dspy/docs/api/local_language_model_clients
# 	File: ./dspy/docs/api/local_language_model_clients/TGI.md
# Content successfully read from ./dspy/docs/api/local_language_model_clients/TGI.md.
#
# 	File: ./dspy/docs/api/local_language_model_clients/Ollama.md
# Content successfully read from ./dspy/docs/api/local_language_model_clients/Ollama.md.
#
# 	File: ./dspy/docs/api/local_language_model_clients/LlamaCpp.md
# Content successfully read from ./dspy/docs/api/local_language_model_clients/LlamaCpp.md.
#
# 	File: ./dspy/docs/api/local_language_model_clients/_category_.json
# Content successfully read from ./dspy/docs/api/local_language_model_clients/_category_.json.
#
# 	File: ./dspy/docs/api/local_language_model_clients/TensorRTLLM.md
# Content successfully read from ./dspy/docs/api/local_language_model_clients/TensorRTLLM.md.
#
# 	File: ./dspy/docs/api/local_language_model_clients/HFModel.md
# Content successfully read from ./dspy/docs/api/local_language_model_clients/HFModel.md.
#
# 	File: ./dspy/docs/api/local_language_model_clients/vLLM.md
# Content successfully read from ./dspy/docs/api/local_language_model_clients/vLLM.md.
#
# 	File: ./dspy/docs/api/local_language_model_clients/MLC.md
# Content successfully read from ./dspy/docs/api/local_language_model_clients/MLC.md.
#
# Current directory: ./dspy/docs/api/optimizers
# 	File: ./dspy/docs/api/optimizers/Ensemble.md
# Content successfully read from ./dspy/docs/api/optimizers/Ensemble.md.
#
# 	File: ./dspy/docs/api/optimizers/BootstrapFewShotWithRandomSearch.md
# Content successfully read from ./dspy/docs/api/optimizers/BootstrapFewShotWithRandomSearch.md.
#
# 	File: ./dspy/docs/api/optimizers/_category_.json
# Content successfully read from ./dspy/docs/api/optimizers/_category_.json.
#
# 	File: ./dspy/docs/api/optimizers/BootstrapFewShot.md
# Content successfully read from ./dspy/docs/api/optimizers/BootstrapFewShot.md.
#
# 	File: ./dspy/docs/api/optimizers/LabeledFewShot.md
# Content successfully read from ./dspy/docs/api/optimizers/LabeledFewShot.md.
#
# 	File: ./dspy/docs/api/optimizers/BootstrapFinetune.md
# Content successfully read from ./dspy/docs/api/optimizers/BootstrapFinetune.md.
#
# Current directory: ./dspy/docs/api/retrieval_model_clients
# 	File: ./dspy/docs/api/retrieval_model_clients/ColBERTv2.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/ColBERTv2.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/WatsonDiscovery.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/WatsonDiscovery.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/MyScaleRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/MyScaleRM.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/ChromadbRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/ChromadbRM.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/_category_.json
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/_category_.json.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/RAGatouilleRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/RAGatouilleRM.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/YouRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/YouRM.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/MilvusRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/MilvusRM.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/Neo4jRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/Neo4jRM.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/FaissRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/FaissRM.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/AzureCognitiveSearch.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/AzureCognitiveSearch.md.
#
# 	File: ./dspy/docs/api/retrieval_model_clients/SnowflakeRM.md
# Content successfully read from ./dspy/docs/api/retrieval_model_clients/SnowflakeRM.md.
#
# Current directory: ./dspy/docs/api/language_model_clients
# 	File: ./dspy/docs/api/language_model_clients/Snowflake.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Snowflake.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Watsonx.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Watsonx.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Groq.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Groq.md.
#
# 	File: ./dspy/docs/api/language_model_clients/TGI.md
# Content successfully read from ./dspy/docs/api/language_model_clients/TGI.md.
#
# 	File: ./dspy/docs/api/language_model_clients/OpenAI.md
# Content successfully read from ./dspy/docs/api/language_model_clients/OpenAI.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Google_VertexAI.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Google_VertexAI.md.
#
# 	File: ./dspy/docs/api/language_model_clients/_category_.json
# Content successfully read from ./dspy/docs/api/language_model_clients/_category_.json.
#
# 	File: ./dspy/docs/api/language_model_clients/Databricks.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Databricks.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Together.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Together.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Cohere.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Cohere.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Mistral.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Mistral.md.
#
# 	File: ./dspy/docs/api/language_model_clients/AzureOpenAI.md
# Content successfully read from ./dspy/docs/api/language_model_clients/AzureOpenAI.md.
#
# 	File: ./dspy/docs/api/language_model_clients/MultiOpenAI.md
# Content successfully read from ./dspy/docs/api/language_model_clients/MultiOpenAI.md.
#
# 	File: ./dspy/docs/api/language_model_clients/PremAI.md
# Content successfully read from ./dspy/docs/api/language_model_clients/PremAI.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Cloudflare.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Cloudflare.md.
#
# 	File: ./dspy/docs/api/language_model_clients/Anyscale.md
# Content successfully read from ./dspy/docs/api/language_model_clients/Anyscale.md.
#
# 	File: ./dspy/docs/api/language_model_clients/aws_providers.md
# Content successfully read from ./dspy/docs/api/language_model_clients/aws_providers.md.
#
# 	File: ./dspy/docs/api/language_model_clients/You.md
# Content successfully read from ./dspy/docs/api/language_model_clients/You.md.
#
# 	File: ./dspy/docs/api/language_model_clients/aws_models.md
# Content successfully read from ./dspy/docs/api/language_model_clients/aws_models.md.
#
# 	File: ./dspy/docs/api/language_model_clients/HFClientVLLM.md
# Content successfully read from ./dspy/docs/api/language_model_clients/HFClientVLLM.md.
#
# Current directory: ./dspy/docs/api/modules
# 	File: ./dspy/docs/api/modules/Retrieve.md
# Content successfully read from ./dspy/docs/api/modules/Retrieve.md.
#
# 	File: ./dspy/docs/api/modules/MultiChainComparison.md
# Content successfully read from ./dspy/docs/api/modules/MultiChainComparison.md.
#
# 	File: ./dspy/docs/api/modules/ProgramOfThought.md
# Content successfully read from ./dspy/docs/api/modules/ProgramOfThought.md.
#
# 	File: ./dspy/docs/api/modules/_category_.json
# Content successfully read from ./dspy/docs/api/modules/_category_.json.
#
# 	File: ./dspy/docs/api/modules/ChainOfThought.md
# Content successfully read from ./dspy/docs/api/modules/ChainOfThought.md.
#
# 	File: ./dspy/docs/api/modules/ChainOfThoughtWithHint.md
# Content successfully read from ./dspy/docs/api/modules/ChainOfThoughtWithHint.md.
#
# 	File: ./dspy/docs/api/modules/ReAct.md
# Content successfully read from ./dspy/docs/api/modules/ReAct.md.
#
# 	File: ./dspy/docs/api/modules/Predict.md
# Content successfully read from ./dspy/docs/api/modules/Predict.md.
#
# Current directory: ./dspy/docs/api/functional
# 	File: ./dspy/docs/api/functional/dspy_predictor.md
# Content successfully read from ./dspy/docs/api/functional/dspy_predictor.md.
#
# 	File: ./dspy/docs/api/functional/dspy_TypedPredictor.md
# Content successfully read from ./dspy/docs/api/functional/dspy_TypedPredictor.md.
#
# 	File: ./dspy/docs/api/functional/_category_.json
# Content successfully read from ./dspy/docs/api/functional/_category_.json.
#
# 	File: ./dspy/docs/api/functional/dspy_TypedCoT.md
# Content successfully read from ./dspy/docs/api/functional/dspy_TypedCoT.md.
#
# 	File: ./dspy/docs/api/functional/dspy_cot.md
# Content successfully read from ./dspy/docs/api/functional/dspy_cot.md.
#
# Current directory: ./dspy/docs/src
# 	Subdirectories: css, components, pages
# Current directory: ./dspy/docs/src/css
# 	File: ./dspy/docs/src/css/custom.css
# Content successfully read from ./dspy/docs/src/css/custom.css.
#
# Current directory: ./dspy/docs/src/components
# 	Subdirectories: HomepageFeatures, AuthorDetails
# Current directory: ./dspy/docs/src/components/HomepageFeatures
# 	File: ./dspy/docs/src/components/HomepageFeatures/index.tsx
# Skipped non-text file: ./dspy/docs/src/components/HomepageFeatures/index.tsx
# 	File: ./dspy/docs/src/components/HomepageFeatures/styles.module.css
# Content successfully read from ./dspy/docs/src/components/HomepageFeatures/styles.module.css.
#
# Current directory: ./dspy/docs/src/components/AuthorDetails
# 	File: ./dspy/docs/src/components/AuthorDetails/index.tsx
# Skipped non-text file: ./dspy/docs/src/components/AuthorDetails/index.tsx
# 	File: ./dspy/docs/src/components/AuthorDetails/styles.module.css
# Content successfully read from ./dspy/docs/src/components/AuthorDetails/styles.module.css.
#
# Current directory: ./dspy/docs/src/pages
# 	File: ./dspy/docs/src/pages/index.tsx
# Skipped non-text file: ./dspy/docs/src/pages/index.tsx
# 	File: ./dspy/docs/src/pages/index.module.css
# Content successfully read from ./dspy/docs/src/pages/index.module.css.
#
# 	File: ./dspy/docs/src/pages/markdown-page.md
# Content successfully read from ./dspy/docs/src/pages/markdown-page.md.

# %%
print(f"There are \033[92m{len(dspy_code)}\033[0m files in dspy/dspy\n")
print(f"There are \033[92m{len(dsp_code)}\033[0m files in dspy/dsp\n")
print(f"There are \033[92m{len(dspy_docs)}\033[0m files in dspy/docs")
# Out:
# There are 105 files in dspy/dspy
#
# There are 57 files in dspy/dsp
#
# There are 103 files in dspy/docs

# %% [markdown]
# ### Test with 1 File
#
# Let's chunk and summarize the code in the DSPy's `WeaviateRM`

# %%
sample = dspy_code[92]
print(sample)
# Out:
# from typing import List, Optional, Union
#
# import dspy
# from dsp.utils import dotdict
# from dspy.primitives.prediction import Prediction
#
# try:
#     import weaviate
# except ImportError as err:
#     raise ImportError(
#         "The 'weaviate' extra is required to use WeaviateRM. Install it with `pip install dspy-ai[weaviate]`",
#     ) from err
#
#
# class WeaviateRM(dspy.Retrieve):
#     """A retrieval module that uses Weaviate to return the top passages for a given query.
#
#     Assumes that a Weaviate collection has been created and populated with the following payload:
#         - content: The text of the passage
#
#     Args:
#         weaviate_collection_name (str): The name of the Weaviate collection.
#         weaviate_client (WeaviateClient): An instance of the Weaviate client.
#         k (int, optional): The default number of top passages to retrieve. Default to 3.
#
#     Examples:
#         Below is a code snippet that shows how to use Weaviate as the default retriever:
#         ```python
#         import weaviate
#
#         llm = dspy.Cohere(model="command-r-plus", api_key=api_key)
#         weaviate_client = weaviate.connect_to_[local, wcs, custom, embedded]("your-path-here")
#         retriever_model = WeaviateRM("my_collection_name", weaviate_client=weaviate_client)
#         dspy.settings.configure(lm=llm, rm=retriever_model)
#
#         retrieve = dspy.Retrieve(k=1)
#         topK_passages = retrieve("what are the stages in planning, sanctioning and execution of public works").passages
#         ```
#
#         Below is a code snippet that shows how to use Weaviate in the forward() function of a module
#         ```python
#         self.retrieve = WeaviateRM("my_collection_name", weaviate_client=weaviate_client, k=num_passages)
#         ```
#     """
#
#     def __init__(
#         self,
#         weaviate_collection_name: str,
#         weaviate_client: Union[weaviate.WeaviateClient, weaviate.Client],
#         weaviate_collection_text_key: Optional[str] = "content",
#         k: int = 3,
#     ):
#         self._weaviate_collection_name = weaviate_collection_name
#         self._weaviate_client = weaviate_client
#         self._weaviate_collection_text_key = weaviate_collection_text_key
#
#         # Check the type of weaviate_client (this is added to support v3 and v4)
#         if hasattr(weaviate_client, "collections"):
#             self._client_type = "WeaviateClient"
#         elif hasattr(weaviate_client, "query"):
#             self._client_type = "Client"
#         else:
#             raise ValueError("Unsupported Weaviate client type")
#
#         super().__init__(k=k)
#
#     def forward(self, query_or_queries: Union[str, List[str]], k: Optional[int] = None, **kwargs) -> Prediction:
#         """Search with Weaviate for self.k top passages for query or queries.
#
#         Args:
#             query_or_queries (Union[str, List[str]]): The query or queries to search for.
#             k (Optional[int]): The number of top passages to retrieve. Defaults to self.k.
#             kwargs :
#
#         Returns:
#             dspy.Prediction: An object containing the retrieved passages.
#         """
#         k = k if k is not None else self.k
#         queries = [query_or_queries] if isinstance(query_or_queries, str) else query_or_queries
#         queries = [q for q in queries if q]
#         passages, parsed_results = [], []
#         for query in queries:
#             if self._client_type == "WeaviateClient":
#                 results = self._weaviate_client.collections.get(self._weaviate_collection_name).query.hybrid(
#                     query=query,
#                     limit=k,
#                     **kwargs,
#                 )
#
#                 parsed_results = [result.properties[self._weaviate_collection_text_key] for result in results.objects]
#
#             elif self._client_type == "Client":
#                 results = (
#                     self._weaviate_client.query.get(
#                         self._weaviate_collection_name,
#                         [self._weaviate_collection_text_key],
#                     )
#                     .with_hybrid(query=query)
#                     .with_limit(k)
#                     .do()
#                 )
#
#                 results = results["data"]["Get"][self._weaviate_collection_name]
#                 parsed_results = [result[self._weaviate_collection_text_key] for result in results]
#
#             passages.extend(dotdict({"long_text": d}) for d in parsed_results)
#
#         return passages

# %%
response = chunker(long_document=sample)

# %%
chunks_with_summaries = response.chunks_with_summaries

# %%
for i in range(5):
    print(f"\033[92m=== Chunk {i} ===\n\033[0m")
    print(f"{chunks_with_summaries[i].chunk}\n")
    print(f"\033[92m=== Summary of Chunk {i} ===\n\033[0m")
    print(f"{chunks_with_summaries[i].summary}\n")
# Out:
# === Chunk 0 ===
#
# from typing import List, Optional, Union
#
# import dspy
# from dsp.utils import dotdict
# from dspy.primitives.prediction import Prediction
#
# try:
#     import weaviate
# except ImportError as err:
#     raise ImportError(
#         "The 'weaviate' extra is required to use WeaviateRM. Install it with `pip install dspy-ai[weaviate]`",
#     ) from err
#
# === Summary of Chunk 0 ===
#
# This section includes the necessary imports for the module, including handling the optional import of the 'weaviate' library with an appropriate error message if it is not installed.
#
# === Chunk 1 ===
#
# class WeaviateRM(dspy.Retrieve):
#     """A retrieval module that uses Weaviate to return the top passages for a given query.
#
#     Assumes that a Weaviate collection has been created and populated with the following payload:
#         - content: The text of the passage
#
#     Args:
#         weaviate_collection_name (str): The name of the Weaviate collection.
#         weaviate_client (WeaviateClient): An instance of the Weaviate client.
#         k (int, optional): The default number of top passages to retrieve. Default to 3.
#
# === Summary of Chunk 1 ===
#
# This section introduces the WeaviateRM class, a retrieval module that uses Weaviate to return top passages for a given query. It outlines the assumptions and arguments required for the class.
#
# === Chunk 2 ===
#
# Examples:
#         Below is a code snippet that shows how to use Weaviate as the default retriever:
#         ```python
#         import weaviate
#
#         llm = dspy.Cohere(model="command-r-plus", api_key=api_key)
#         weaviate_client = weaviate.connect_to_[local, wcs, custom, embedded]("your-path-here")
#         retriever_model = WeaviateRM("my_collection_name", weaviate_client=weaviate_client)
#         dspy.settings.configure(lm=llm, rm=retriever_model)
#
#         retrieve = dspy.Retrieve(k=1)
#         topK_passages = retrieve("what are the stages in planning, sanctioning and execution of public works").passages
#         ```
#
# === Summary of Chunk 2 ===
#
# This section provides an example code snippet demonstrating how to use Weaviate as the default retriever in a dspy setup.
#
# === Chunk 3 ===
#
# Below is a code snippet that shows how to use Weaviate in the forward() function of a module
#         ```python
#         self.retrieve = WeaviateRM("my_collection_name", weaviate_client=weaviate_client, k=num_passages)
#         ```
#     """
#
#     def __init__(
#         self,
#         weaviate_collection_name: str,
#         weaviate_client: Union[weaviate.WeaviateClient, weaviate.Client],
#         weaviate_collection_text_key: Optional[str] = "content",
#         k: int = 3,
#     ):
#
# === Summary of Chunk 3 ===
#
# This section provides another example code snippet showing how to use Weaviate in the forward() function of a module. It also begins the definition of the WeaviateRM class constructor.
#
# === Chunk 4 ===
#
# self._weaviate_collection_name = weaviate_collection_name
#         self._weaviate_client = weaviate_client
#         self._weaviate_collection_text_key = weaviate_collection_text_key
#
#         # Check the type of weaviate_client (this is added to support v3 and v4)
#         if hasattr(weaviate_client, "collections"):
#             self._client_type = "WeaviateClient"
#         elif hasattr(weaviate_client, "query"):
#             self._client_type = "Client"
#         else:
#             raise ValueError("Unsupported Weaviate client type")
#
#         super().__init__(k=k)
#
# === Summary of Chunk 4 ===
#
# This section continues the constructor of the WeaviateRM class, initializing instance variables and checking the type of the Weaviate client to ensure compatibility with different versions.

# %% [markdown]
# # 4. Chunk and Import!

# %%
import weaviate
weaviate_client = weaviate.connect_to_local()
weaviate_client.collections.delete_all()

# %%
import weaviate
import weaviate.classes.config as wvcc

weaviate_client = weaviate.connect_to_local()

code_collection = weaviate_client.collections.create(
    name="Code",
    vectorizer_config=wvcc.Configure.Vectorizer.text2vec_voyageai(
        model="voyage-code-2"
    ),
    properties=[
        wvcc.Property(name="content", data_type=wvcc.DataType.TEXT),
        wvcc.Property(name="chunk_summary", data_type=wvcc.DataType.TEXT)
    ]
)

docs_collection = weaviate_client.collections.create(
    name="Docs",
    vectorizer_config=wvcc.Configure.Vectorizer.text2vec_cohere(
        model="embed-english-v3.0"
    ),
    properties=[
        wvcc.Property(name="content", data_type=wvcc.DataType.TEXT),
        wvcc.Property(name="chunk_summary", data_type=wvcc.DataType.TEXT)
    ]
)
# Out:
# /Users/cshorten/Library/Caches/pypoetry/virtualenvs/weaviate-agents-8ZuJxa4C-py3.10/lib/python3.10/site-packages/weaviate/warnings.py:303: ResourceWarning: Con004: The connection to Weaviate was not closed properly. This can lead to memory leaks.
#             Please make sure to close the connection using `client.close()`.
#   warnings.warn(

# %% [markdown]
# ## DSPy's Typed Predictors
#
# DSPy currently supports several strategies for achieving structured outputs with LLM systems.
#
# Here are some thoughts from the Weaviate team on our developing understanding of structured outputs:
# - StructuredRAG - [[repo]](https://github.com/weaviate/structured-rag/tree/main)
# - OPRO JSON Mode [[notebook]](https://github.com/weaviate/structured-rag/blob/main/OPRO-Compiled-JSON-Mode.ipynb)
# - Weaviate Podcast #88 with Jason Liu [[podcast]](https://www.youtube.com/watch?v=higlHgYDc5E)
# - Weaviate Recipes [[notebook]](https://github.com/weaviate/recipes/blob/main/integrations/llm-frameworks/dspy/4.Structured-Outputs-with-DSPy.ipynb)

# %%
from weaviate.util import get_valid_uuid
from uuid import uuid4

failure_counter = 0

import time

start = time.time()
for file in dspy_code:
    try:
        response = chunker(long_document=file)
        # file_summary = response.file_summary # ToDo
        chunks_with_summaries = response.chunks_with_summaries
        for chunk_with_summary in chunks_with_summaries:
            uuid = get_valid_uuid(uuid4())
            code_collection.data.insert(
                properties={
                    "content": chunk_with_summary.chunk,
                    "summary": chunk_with_summary.summary
                },
                uuid=uuid
            )
    except:
        failure_counter += 1
        print(f"TypedPredictors failure {failure_counter}\n")
print(f"GFL ran in {time.time() - start} seconds.")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/selector_events.py:710: ResourceWarning: unclosed transport <_SelectorSocketTransport fd=87 read=idle write=<idle, bufsize=0>>
#   _warn(f"unclosed transport {self!r}", ResourceWarning, source=self)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/selector_events.py:710: ResourceWarning: unclosed transport <_SelectorSocketTransport fd=89 read=idle write=<idle, bufsize=0>>
#   _warn(f"unclosed transport {self!r}", ResourceWarning, source=self)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# TypedPredictors failure 1
#
# TypedPredictors failure 2
#
# TypedPredictors failure 3
#
# TypedPredictors failure 4
#
# TypedPredictors failure 5
#
# TypedPredictors failure 6
#
# GFL ran in 208.73269414901733 seconds.

# %%
start = time.time()
for file in dspy_code:
    try:
        response = chunker(long_document=file)
        # file_summary = response.file_summary # ToDo
        chunks_with_summaries = response.chunks_with_summaries
        for chunk_with_summary in chunks_with_summaries:
            uuid = get_valid_uuid(uuid4())
            code_collection.data.insert(
                properties={
                    "content": chunk_with_summary.chunk,
                    "summary": chunk_with_summary.summary
                },
                uuid=uuid
            )
    except:
        failure_counter += 1
        print(f"TypedPredictors failure {failure_counter}\n")
print(f"GFL ran in {time.time() - start} seconds.")
# Out:
# TypedPredictors failure 7
#
# TypedPredictors failure 8
#
# TypedPredictors failure 9
#
# TypedPredictors failure 10
#
# TypedPredictors failure 11
#
# TypedPredictors failure 12
#
# GFL ran in 198.70638418197632 seconds.

# %%
start = time.time()
for file in dspy_docs:
    try:
        response = chunker(long_document=file)
        # file_summary = response.file_summary # ToDo
        chunks_with_summaries = response.chunks_with_summaries
        for chunk_with_summary in chunks_with_summaries:
            uuid = get_valid_uuid(uuid4())
            docs_collection.data.insert(
                properties={
                    "content": chunk_with_summary.chunk,
                    "summary": chunk_with_summary.summary
                },
                uuid=uuid
            )
    except:
        failure_counter += 1
        print(f"TypedPredictors failure {failure_counter}\n")
print(f"GFL ran in {time.time() - start} seconds.")
# Out:
# TypedPredictors failure 13
#
# TypedPredictors failure 14
#
# TypedPredictors failure 15
#
# TypedPredictors failure 16
#
# TypedPredictors failure 17
# INFO:backoff:Backing off request(...) for 0.6s (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# Backing off 0.6 seconds after 1 tries calling function <function GPT3.request at 0x1155bb130> with kwargs {}
# INFO:backoff:Backing off request(...) for 0.5s (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# Backing off 0.5 seconds after 2 tries calling function <function GPT3.request at 0x1155bb130> with kwargs {}
# INFO:backoff:Backing off request(...) for 1.9s (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# Backing off 1.9 seconds after 3 tries calling function <function GPT3.request at 0x1155bb130> with kwargs {}
# ERROR:backoff:Giving up request(...) after 4 tries (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# TypedPredictors failure 18
# INFO:backoff:Backing off request(...) for 0.6s (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# Backing off 0.6 seconds after 1 tries calling function <function GPT3.request at 0x1155bb130> with kwargs {}
# INFO:backoff:Backing off request(...) for 1.6s (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# Backing off 1.6 seconds after 2 tries calling function <function GPT3.request at 0x1155bb130> with kwargs {}
# INFO:backoff:Backing off request(...) for 1.4s (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# Backing off 1.4 seconds after 3 tries calling function <function GPT3.request at 0x1155bb130> with kwargs {}
# ERROR:backoff:Giving up request(...) after 4 tries (openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}})
# TypedPredictors failure 19
#
# GFL ran in 80.71587681770325 seconds.

# %% [markdown]
# # Check Data in Weaviate!

# %%
response = code_collection.aggregate.over_all(total_count=True)

print(f"{response.total_count} objects in the Weaviate \033[92m`Code`\033[0m collection.")

response = docs_collection.aggregate.over_all(total_count=True)

print(f"{response.total_count} objects in the Weaviate \033[92m`Docs`\033[0m collection.")
# Out:
# 1242 objects in the Weaviate `Code` collection.
# 418 objects in the Weaviate `Docs` collection.

# %% [markdown]
# # Search through your Data in Weaviate!

# %%
response = code_collection.query.hybrid(query="WeaviateRM", limit=3)

for o in response.objects:
    print("=== Content ===\n")
    print(o.properties["content"])
    print("\n=== Summary ===\n")
    print(o.properties["summary"])
    print("\n")
# Out:
# === Content ===
#
# self._weaviate_collection_name = weaviate_collection_name
#         self._weaviate_client = weaviate_client
#         self._weaviate_collection_text_key = weaviate_collection_text_key
#
#         # Check the type of weaviate_client (this is added to support v3 and v4)
#         if hasattr(weaviate_client, "collections"):
#             self._client_type = "WeaviateClient"
#         elif hasattr(weaviate_client, "query"):
#             self._client_type = "Client"
#         else:
#             raise ValueError("Unsupported Weaviate client type")
#
#         super().__init__(k=k)
#
# === Summary ===
#
# This section continues the constructor of the WeaviateRM class, initializing instance variables and checking the type of the Weaviate client to ensure compatibility with different versions.
#
#
# === Content ===
#
# self._weaviate_collection_name = weaviate_collection_name
#         self._weaviate_client = weaviate_client
#         self._weaviate_collection_text_key = weaviate_collection_text_key
#
#         # Check the type of weaviate_client (this is added to support v3 and v4)
#         if hasattr(weaviate_client, "collections"):
#             self._client_type = "WeaviateClient"
#         elif hasattr(weaviate_client, "query"):
#             self._client_type = "Client"
#         else:
#             raise ValueError("Unsupported Weaviate client type")
#
#         super().__init__(k=k)
#
# === Summary ===
#
# This section continues the constructor of the WeaviateRM class, initializing instance variables and checking the type of the Weaviate client to ensure compatibility with different versions.
#
#
# === Content ===
#
# Below is a code snippet that shows how to use Weaviate in the forward() function of a module
#         ```python
#         self.retrieve = WeaviateRM("my_collection_name", weaviate_client=weaviate_client, k=num_passages)
#         ```
#     """
#
#     def __init__(
#         self,
#         weaviate_collection_name: str,
#         weaviate_client: Union[weaviate.WeaviateClient, weaviate.Client],
#         weaviate_collection_text_key: Optional[str] = "content",
#         k: int = 3,
#     ):
#
# === Summary ===
#
# This section provides another example code snippet showing how to use Weaviate in the forward() function of a module. It also begins the definition of the WeaviateRM class constructor.

# %% [markdown]
# # Connect with us!
#
# I hope you found this example useful to see how Semantic Chunking with Generative Feedback Loops can help you prepare your data for Vector Database and LLM Applications!
#
# Please reach out to us if you would like to discuss applications of Generative Feedback Loops in your project, and please feel free to open a pull request to add your GFL examples to Weaviate Recipes!
