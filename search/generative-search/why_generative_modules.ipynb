# %% [markdown]
# # Why should I use Weaviate Modules?
#
# ### TLDR: Weaviate's GraphQL RAG API is `~550 times faster` compared to a Python Client Handoff

# %% [markdown]
# Weaviate's Modules tightly integrate inference APIs with the database's query processing.
#
# For example, Weaviate's `generate` API parses the response from vector search, sends a direct request to an LLM API, and then parses the response.
#
# This is orchestrated with Golang, a programming language mostly famous for it's concurrency support and applications in web servers.
#
# This notebook will illustrated the speed differeneces between Weaviate's `generate` API with parsing a request from the python client to send to an LLM provider's python client (which we reference as DIY).
#
# ## DIY: 3.3 seconds
#
# ## Weaviate GraphQL: 7 milliseconds

# %%
import weaviate
from openai import OpenAI
import json

client = weaviate.connect_to_local()  # Connect with default parameters

openai_client = OpenAI(api_key = openai_api_key)

# %%
import time

# Initialize arrays for saving responses and times
#responses = [] #ToDo
execution_times = []

# Client setup (assuming it's already configured)
blogs = client.collections.get("WeaviateBlogChunk")

for idx in range(10):
    start = time.time()
    
    # Perform the query
    response = blogs.query.near_text(
        query="What are cross encoders?",
        limit=5
    )
    
    # Extract and concatenate the results
    results = []
    for o in response.objects:
        results.append(o.properties["content"])
    results_joined = "".join(results)
    
    prompt = f"{results_joined} \n Based on the context, what are cross encoders?"
    
    # Generate response using OpenAI client (assuming it's already configured)
    response = openai_client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages = [
          {
              "role": "user",
              "content": prompt
          }
      ],
      temperature=0,
      max_tokens=2048,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )
    
    # Save the response and the execution time
    execution_times.append(time.time() - start)
    #responses.append(response.choices[0].message.content), #ToDo test with higher temperature
    
# Calculate summary statistics
average_time = np.mean(execution_times)
min_time = min(execution_times)
max_time = max(execution_times)

print(f"Average execution time: {average_time} seconds \n \n")
print(f"Minimum execution time: {min_time} seconds")
print(f"Maximum execution time: {max_time} seconds")

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(range(1, 11), execution_times, color='skyblue')
plt.xlabel('Iteration')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Time for Each Iteration')
plt.xticks(range(1, 11))
plt.axhline(y=average_time, color='r', linestyle='-', label=f'Average Time: {average_time:.2f}s')
plt.legend()
plt.show()
# Out:
# Average execution time: 3.3198646783828734 seconds
#
#
# Minimum execution time: 2.391869306564331 seconds
# Maximum execution time: 4.143470048904419 seconds

# %% [markdown]
# # GraphQL API

# %%
import time
import matplotlib.pyplot as plt
import numpy as np

# Assuming the client setup is already done

# Initialize arrays for saving latencies
latencies = []

for _ in range(10):
    start = time.time()
    
    # Execute the GraphQL query
    response = client.graphql_raw_query("""
    {
        Get {
            WeaviateBlogChunk (
                    nearText: {
                        concepts: ["What are cross encoders?"]
                    },
                    limit: 5
                ) {
                content
                _additional {
                    generate(
                        groupedResult: {
                            task: "What are cross encoders?"
                        }
                    )
                }
            }
        }
    }
    """)
    
    # Log the latency
    latencies.append(time.time() - start)

# Calculate summary statistics
average_latency = np.mean(latencies)
min_latency = min(latencies)
max_latency = max(latencies)

print(f"Average execution time: {average_latency} seconds \n \n")
print(f"Minimum execution time: {min_latency} seconds")
print(f"Maximum execution time: {max_latency} seconds")

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(range(1, 11), latencies, color='skyblue')
plt.xlabel('Iteration')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Time for Each Iteration')
plt.xticks(range(1, 11))
plt.axhline(y=average_latency, color='r', linestyle='-', label=f'Average Time: {average_latency:.2f}s')
plt.legend()
plt.show()
# Out:
# Average execution time: 0.006087470054626465 seconds
#
#
# Minimum execution time: 0.0027108192443847656 seconds
# Maximum execution time: 0.021660804748535156 seconds

# %% [markdown]
# # WIP gRPC Test

# %%
blogs = client.collections.get("WeaviateBlogChunk")
start = time.time()
response = blogs.generate.near_text(
    query="What are cross encoders?",
    limit=5,
    grouped_task="What do these animals have in common?",
)

# Parsing omitted
'''
print(response.generated)  # Generated text from grouped task
for o in response.objects:
    print(o.generated)  # Generated text from single prompt
    print(o.properties)  # Object properties
'''

print(f"With Weaviate Modules: One RAG query ran in {time.time() - start} seconds")
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/weaviate/collections/grpc/query.py:563, in _QueryGRPC.__call(self)
#     562 res: search_get_pb2.SearchReply  # According to PEP-0526
# --> 563 res, _ = self._connection.grpc_stub.Search.with_call(
#     564     search_get_pb2.SearchRequest(
#     565         uses_123_api=True,
#     566         collection=self._name,
#     567         limit=self._limit,
#     568         offset=self._offset,
#     569         after=str(self._after) if self._after is not None else "",
#     570         autocut=self._autocut,
#     571         near_vector=(
#     572             search_get_pb2.NearVector(
#     573                 certainty=self._near_certainty,
#     574                 distance=self._near_distance,
#     575                 vector_bytes=struct.pack(
#     576                     "{}f".format(len(self._near_vector_vec)), *self._near_vector_vec
#     577                 ),
#     578             )
#     579             if self._near_vector_vec is not None
#     580             else None
#     581         ),
#     582         near_object=(
#     583             search_get_pb2.NearObject(
#     584                 id=str(self._near_object_obj),
#     585                 certainty=self._near_certainty,
#     586                 distance=self._near_distance,
#     587             )
#     588             if self._near_object_obj is not None
#     589             else None
#     590         ),
#     591         properties=self._translate_properties_from_python_to_grpc(
#     592             self._return_props, self._return_refs
#     593         ),
#     594         metadata=(
#     595             self._metadata_to_grpc(self._metadata)
#     596             if self._metadata is not None
#     597             else None
#     598         ),
#     599         bm25_search=(
#     600             search_get_pb2.BM25(
#     601                 properties=self._bm25_properties, query=self._bm25_query
#     602             )
#     603             if self._bm25_query is not None
#     604             else None
#     605         ),
#     606         hybrid_search=(
#     607             search_get_pb2.Hybrid(
#     608                 properties=self._hybrid_properties,
#     609                 query=self._hybrid_query,
#     610                 alpha=self._hybrid_alpha,
#     611                 fusion_type=cast(
#     612                     search_get_pb2.Hybrid.FusionType, self._hybrid_fusion_type
#     613                 ),
#     614                 vector_bytes=(
#     615                     struct.pack(
#     616                         "{}f".format(len(self._hybrid_vector)), *self._hybrid_vector
#     617                     )
#     618                     if self._hybrid_vector is not None
#     619                     else None
#     620                 ),
#     621             )
#     622             if self._hybrid_query is not None
#     623             else None
#     624         ),
#     625         tenant=self._tenant,
#     626         filters=_FilterToGRPC.convert(self._filters),
#     627         near_audio=(
#     628             search_get_pb2.NearAudioSearch(
#     629                 audio=self._near_audio,
#     630                 distance=self._near_distance,
#     631                 certainty=self._near_certainty,
#     632             )
#     633             if self._near_audio is not None
#     634             else None
#     635         ),
#     636         near_depth=(
#     637             search_get_pb2.NearDepthSearch(
#     638                 depth=self._near_depth,
#     639                 distance=self._near_distance,
#     640                 certainty=self._near_certainty,
#     641             )
#     642             if self._near_depth is not None
#     643             else None
#     644         ),
#     645         near_image=(
#     646             search_get_pb2.NearImageSearch(
#     647                 image=self._near_image,
#     648                 distance=self._near_distance,
#     649                 certainty=self._near_certainty,
#     650             )
#     651             if self._near_image is not None
#     652             else None
#     653         ),
#     654         near_imu=(
#     655             search_get_pb2.NearIMUSearch(
#     656                 imu=self._near_imu,
#     657                 distance=self._near_distance,
#     658                 certainty=self._near_certainty,
#     659             )
#     660             if self._near_imu is not None
#     661             else None
#     662         ),
#     663         near_text=(
#     664             search_get_pb2.NearTextSearch(
#     665                 query=self._near_text,
#     666                 certainty=self._near_certainty,
#     667                 distance=self._near_distance,
#     668                 move_to=self._near_text_move_to,
#     669                 move_away=self._near_text_move_away,
#     670             )
#     671             if self._near_text is not None
#     672             else None
#     673         ),
#     674         near_thermal=(
#     675             search_get_pb2.NearThermalSearch(
#     676                 thermal=self._near_thermal,
#     677                 distance=self._near_distance,
#     678                 certainty=self._near_certainty,
#     679             )
#     680             if self._near_thermal is not None
#     681             else None
#     682         ),
#     683         near_video=(
#     684             search_get_pb2.NearVideoSearch(
#     685                 video=self._near_video,
#     686                 distance=self._near_distance,
#     687                 certainty=self._near_certainty,
#     688             )
#     689             if self._near_video is not None
#     690             else None
#     691         ),
#     692         consistency_level=self._consistency_level,
#     693         sort_by=(
#     694             [
#     695                 search_get_pb2.SortBy(ascending=sort.ascending, path=[sort.prop])
#     696                 for sort in self._sort
#     697             ]
#     698             if self._sort is not None
#     699             else None
#     700         ),
#     701         generative=self._generative.to_grpc() if self._generative is not None else None,
#     702         group_by=self._group_by.to_grpc() if self._group_by is not None else None,
#     703         rerank=(
#     704             search_get_pb2.Rerank(property=self._rerank.prop, query=self._rerank.query)
#     705             if self._rerank is not None
#     706             else None
#     707         ),
#     708     ),
#     709     metadata=metadata,
#     710     timeout=self._connection.timeout_config.connect,
#     711 )
#     713 return res
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/grpc/_channel.py:1177, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1171 (
#    1172     state,
#    1173     call,
#    1174 ) = self._blocking(
#    1175     request, timeout, metadata, credentials, wait_for_ready, compression
#    1176 )
# -> 1177 return _end_unary_response_blocking(state, call, True, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/grpc/_channel.py:1003, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1002 else:
# -> 1003     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "explorer: get class: extend: unknown capability: generate"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"explorer: get class: extend: unknown capability: generate", grpc_status:2, created_time:"2024-02-27T19:26:06.860767-05:00"}"
# >
#
# During handling of the above exception, another exception occurred:
#
# WeaviateQueryError                        Traceback (most recent call last)
# Cell In[9], line 3
#       1 blogs = client.collections.get("WeaviateBlogChunk")
#       2 start = time.time()
# ----> 3 response = blogs.generate.near_text(
#       4     query="What are cross encoders?",
#       5     limit=5,
#       6     grouped_task="What do these animals have in common?",
#       7 )
#       9 # Parsing omitted
#      10 '''
#      11 print(response.generated)  # Generated text from grouped task
#      12 for o in response.objects:
#      13     print(o.generated)  # Generated text from single prompt
#      14     print(o.properties)  # Object properties
#      15 '''
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/weaviate/collections/queries/near_text/generate.py:93, in _NearTextGenerate.near_text(self, query, single_prompt, grouped_task, grouped_properties, certainty, distance, move_to, move_away, limit, offset, auto_limit, filters, group_by, rerank, include_vector, return_metadata, return_properties, return_references)
#      26 def near_text(
#      27     self,
#      28     query: Union[List[str], str],
#    (...)
#      46     return_references: Optional[ReturnReferences[TReferences]] = None,
#      47 ) -> GenerativeNearMediaReturnType[Properties, References, TProperties, TReferences]:
#      48     """Perform retrieval-augmented generation (RaG) on the results of a by-image object search in this collection using the image-capable vectorization module and vector-based similarity search.
#      49
#      50     See the [docs](https://weaviate.io/developers/weaviate/api/graphql/search-operators#neartext) for a more detailed explanation.
#    (...)
#      91             If the request to the Weaviate server fails.
#      92     """
# ---> 93     res = self._query().near_text(
#      94         near_text=query,
#      95         certainty=certainty,
#      96         distance=distance,
#      97         move_to=move_to,
#      98         move_away=move_away,
#      99         limit=limit,
#     100         offset=offset,
#     101         autocut=auto_limit,
#     102         filters=filters,
#     103         group_by=_GroupBy.from_input(group_by),
#     104         rerank=rerank,
#     105         generative=_Generative(
#     106             single=single_prompt,
#     107             grouped=grouped_task,
#     108             grouped_properties=grouped_properties,
#     109         ),
#     110         return_metadata=self._parse_return_metadata(return_metadata, include_vector),
#     111         return_properties=self._parse_return_properties(return_properties),
#     112         return_references=self._parse_return_references(return_references),
#     113     )
#     114     return self._result_to_generative_return(
#     115         res,
#     116         _QueryOptions.from_input(
#    (...)
#     126         return_references,
#     127     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/weaviate/collections/grpc/query.py:493, in _QueryGRPC.near_text(self, near_text, certainty, distance, move_to, move_away, limit, offset, autocut, filters, group_by, generative, rerank, return_metadata, return_properties, return_references)
#     489 if move_to is not None:
#     490     self._near_text_move_to = search_get_pb2.NearTextSearch.Move(
#     491         force=move_to.force, concepts=move_to._concepts_list, uuids=move_to._objects_list
#     492     )
# --> 493 return self.__call()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/weaviate/collections/grpc/query.py:716, in _QueryGRPC.__call(self)
#     713     return res
#     715 except grpc.RpcError as e:
# --> 716     raise WeaviateQueryError(e.details(), "GRPC search")
#
# WeaviateQueryError: Query call with protocol GRPC search failed with message explorer: get class: extend: unknown capability: generate.
